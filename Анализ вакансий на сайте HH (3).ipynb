# %% [markdown]
# # **Исследование вакансий "Аналитик данных" и "Data Scientist", размещенных на сайте hh.ru**

# %% [markdown]
# ## **Описание проекта**
#
# Анализ данных вакансий сайта HH.ru

# %% [markdown]
# ## **Цель проекта**
#
# Выявить различия в предлагаемых вакансиях для Аналитиков данных и Специалистов по Data Science.

# %% [markdown]
# ## **Исходные данные**
#
# Данные получены из API сайта HH.ru. Данные прошли предварительную обработку и очистку.

# %% [markdown]
# ## **Описание полей**
# ![image.png](attachment:b712fbb3-66ec-4032-91a5-47002bc339d1.png)

# %% [markdown]
# ## 1. Выполнение загрузки данных

# %%
# импортируем необходимые библиотеки
import pandas as pd
from collections import Counter
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
data_da_f = pd.read_excel(r'C:/Users/Admin/Downloads/vacancies_da.xlsx') # читаем файл с данными

# %%
data_da_f.head(10) # выводим первые 10 строк
# Out:
#           id                                    name        published_at  \
# 0  100039284  Junior аналитик данных (исследователь) 2024-05-24 09:37:04
# 1  100039480                         Аналитик данных 2024-05-24 09:39:00
# 2  100042705         Аналитик данных (исследователь) 2024-05-24 10:01:25
# 3  100046788                 Ведущий аналитик данных 2024-05-24 10:28:18
# 4  100056244                         Аналитик данных 2024-05-24 11:27:40
# 5  100059110   Senior Data Analyst (Цифровой билайн) 2024-06-11 11:45:29
# 6  100060772                         Аналитик данных 2024-05-24 11:56:20
# 7  100069131                           Дата аналитик 2024-05-24 13:05:01
# 8  100069821                         Аналитик данных 2024-06-10 16:49:49
# 9  100071014                         Аналитик данных 2024-06-07 11:08:22
#
#                      alternate_url      type  \
# 0  https://hh.ru/vacancy/100039284  Открытая
# 1  https://hh.ru/vacancy/100039480  Открытая
# 2  https://hh.ru/vacancy/100042705  Открытая
# 3  https://hh.ru/vacancy/100046788  Открытая
# 4  https://hh.ru/vacancy/100056244  Открытая
# 5  https://hh.ru/vacancy/100059110  Открытая
# 6  https://hh.ru/vacancy/100060772  Открытая
# 7  https://hh.ru/vacancy/100069131  Открытая
# 8  https://hh.ru/vacancy/100069821  Открытая
# 9  https://hh.ru/vacancy/100071014  Открытая
#
#                                       employer                  department  \
# 0                            DNS Головной офис                         NaN
# 1                                        Комус                         NaN
# 2                            DNS Головной офис                         NaN
# 3                                     Х5 Group  X5 GROUP, Центральный офис
# 4                                       ЛУКОЙЛ                         NaN
# 5                                       билайн   билайн: ИТ, Data, Digital
# 6  ГКУ Центр занятости населения города Москвы                         NaN
# 7                                         СБЕР          Сбер для экспертов
# 8                                          МТС                      «МТС»
# 9                                 Россети Урал                         NaN
#
#               area             experience  \
# 0      Владивосток  Junior (no experince)
# 1           Москва  Junior (no experince)
# 2      Владивосток    Junior+ (1-3 years)
# 3           Москва    Junior+ (1-3 years)
# 4           Москва     Middle (3-6 years)
# 5           Москва     Middle (3-6 years)
# 6           Москва    Junior+ (1-3 years)
# 7  Санкт-Петербург    Junior+ (1-3 years)
# 8           Казань    Junior+ (1-3 years)
# 9     Екатеринбург    Junior+ (1-3 years)
#
#                                           key_skills          schedule  \
# 0              ['Power BI', 'СУБД', 'Python', 'SQL']       Полный день
# 1   ['MS SQL', 'Работа с базами данных', 'MS Excel']       Полный день
# 2  ['SQL', 'Power BI', 'СУБД', 'Python', 'Clickho...       Полный день
# 3  ['Анализ данных', 'Коммуникация', 'SQL', 'MS O...       Полный день
# 4                                   ['Документация']       Полный день
# 5     ['Python', 'SQL', 'Математическая статистика']  Удаленная работа
# 6                                                 []       Полный день
# 7  ['Документация', 'Проактивность', 'Коммуникация']       Полный день
# 8                                                 []       Полный день
# 9                         ['Аналитическое мышление']       Полный день
#
#          employment                                        description  \
# 0  Полная занятость  наше направление занимается повышением эффекти...
# 1  Полная занятость  сегодня комус один из крупнейших поставщиков о...
# 2  Полная занятость  наше направление занимается повышением эффекти...
# 3  Полная занятость  задачи:  разработка бизнес-моделей для группов...
# 4  Полная занятость  обязанности:  участие в проектировании, разраб...
# 5  Полная занятость  сегодня билайн — компания изменений, чутко реа...
# 6  Полная занятость  один из ключевых партнеров центра занятости на...
# 7  Полная занятость  команда данных по инвестиционным продуктам. мы...
# 8  Полная занятость  мтс — это мультисервисная цифровая экосистема....
# 9  Полная занятость  пао «россети урал» — крупнейшая электросетевая...
#
#                               description_lemmatized  salary_from  salary_to  \
# 0  наш направление заниматься повышение эффективн...      60000.0        NaN
# 1  сегодня комус крупный поставщик офисный товар ...          NaN        NaN
# 2  наш направление заниматься повышение эффективн...      90000.0        NaN
# 3  задача разработка бизнес модель групповой прог...          NaN        NaN
# 4  обязанность участие проектирование разработка ...          NaN        NaN
# 5  сегодня билайн компания изменение чутко реагир...          NaN        NaN
# 6  ключевой партнер центр занятость население раб...     100000.0        NaN
# 7  команда данные инвестиционный продукт развиват...          NaN        NaN
# 8  мтс мультисервисный цифровой экосистема создав...      72000.0        NaN
# 9  россеть урал крупный электросетевой компания у...      51000.0        NaN
#
#       salary_bin                   key_skills_from_key_skills_field  \
# 0  ЗП не указана                        SQL, Power BI, Python, СУБД
# 1  ЗП не указана           Работа с базами данных, MS SQL, MS Excel
# 2  ЗП не указана      SQL, Power BI, Python, СУБД, BPMN, Clickhouse
# 3  ЗП не указана  MS Office, SQL, Python, Hadoop, Нive, Аналитич...
# 4  ЗП не указана                                                NaN
# 5  ЗП не указана             Python, SQL, Математическая статистика
# 6  ЗП не указана                                                NaN
# 7  ЗП не указана                                                NaN
# 8  ЗП не указана                                                NaN
# 9  ЗП не указана                                                NaN
#
#   hard_skills_from_description               soft_skills_from_description
# 0                          NaN                                        NaN
# 1                          NaN                                        NaN
# 2                          NaN                                        NaN
# 3       Pandas, Юнит-экономика                               Коммуникация
# 4                          NaN                               Документация
# 5                          NaN                                        NaN
# 6                          NaN                                        NaN
# 7                          NaN  Коммуникация, Документация, Проактивность
# 8                          NaN                                        NaN
# 9                          NaN                     Аналитическое мышление

# %%
data_ds_f = pd.read_excel('C:/Users/Admin/Downloads/vacancies_ds.xlsx') # читаем файл с данными

# %%
data_ds_f.head(10) # выводим первые 10 строк
# Out:
#           id                                name        published_at  \
# 0  100049339   Стажер Data Science (Новосибирск) 2024-05-24 10:44:01
# 1  100051447                      Data Scientist 2024-05-24 10:58:18
# 2  100070495        ML Engineer / Data Scientist 2024-05-24 13:15:26
# 3  100076648              Team Lead Data Science 2024-05-24 14:07:00
# 4  100077910       Data Analyst / Data Scientist 2024-06-08 14:17:47
# 5  100079219           Senior Data Scientist MLE 2024-06-08 14:29:15
# 6  100088790                      Data Scientist 2024-05-24 15:44:41
# 7  100094269  Middle/Senior Data Scientist (LLM) 2024-05-24 16:33:00
# 8  100096283                Эксперт Data Science 2024-05-24 16:56:18
# 9  100096836           Data Scientist/Data miner 2024-05-24 17:01:31
#
#                      alternate_url      type  \
# 0  https://hh.ru/vacancy/100049339  Открытая
# 1  https://hh.ru/vacancy/100051447  Открытая
# 2  https://hh.ru/vacancy/100070495  Открытая
# 3  https://hh.ru/vacancy/100076648  Открытая
# 4  https://hh.ru/vacancy/100077910  Открытая
# 5  https://hh.ru/vacancy/100079219  Открытая
# 6  https://hh.ru/vacancy/100088790  Открытая
# 7  https://hh.ru/vacancy/100094269  Открытая
# 8  https://hh.ru/vacancy/100096283  Открытая
# 9  https://hh.ru/vacancy/100096836  Открытая
#
#                               employer               department  \
# 0                                 СБЕР       Сбер для экспертов
# 1  Бюро кредитных историй Скоринг Бюро                      NaN
# 2                               ГК ФСК                      NaN
# 3                                 СБЕР       Сбер для экспертов
# 4                                Итсен                      NaN
# 5                            Автомакон                      NaN
# 6                           Ростелеком                      NaN
# 7                                 СБЕР       Сбер для экспертов
# 8                           МТС Финтех  МТС Банк. Головной офис
# 9                          Интерлизинг                      NaN
#
#               area             experience  \
# 0      Новосибирск  Junior (no experince)
# 1           Москва    Junior+ (1-3 years)
# 2           Москва    Junior+ (1-3 years)
# 3           Москва     Middle (3-6 years)
# 4           Москва     Middle (3-6 years)
# 5           Москва     Middle (3-6 years)
# 6  Санкт-Петербург    Junior+ (1-3 years)
# 7           Москва     Middle (3-6 years)
# 8           Москва    Junior+ (1-3 years)
# 9  Санкт-Петербург    Junior+ (1-3 years)
#
#                                           key_skills          schedule  \
# 0                                                 []       Полный день
# 1  ['Python', 'Hadoop', 'Machine Learning', 'Рабо...  Удаленная работа
# 2  ['Python', 'PyTorch', 'Machine Learning', 'Doc...       Полный день
# 3                                                 []       Полный день
# 4  ['DataLens', 'MS SQL', 'SQL', 'Spark', 'Аналит...       Полный день
# 5  ['Python', 'sklearn', 'PostgreSQL', 'numpy', '...  Удаленная работа
# 6  ['Python', 'Machine Learning', 'SQL', 'Big Dat...  Удаленная работа
# 7                                                 []       Полный день
# 8                  ['Python', 'Документация', 'SQL']       Полный день
# 9  ['Python', 'Работа с базами данных', 'Статисти...       Полный день
#
#          employment                                        description  \
# 0        Стажировка  sberseasons - оплачиваемая программа стажирово...
# 1  Полная занятость  бюро кредитных историй «скоринг бюро» является...
# 2  Полная занятость  о компании и команде: группа компаний фск – мн...
# 3  Полная занятость  наша команда разрабатывает модели машинного об...
# 4  Полная занятость  мы ищем талантливого middle data analyst / dat...
# 5  Полная занятость  обязанности:  собирать данные из dwh; эксперим...
# 6  Полная занятость  привет, будущий заклинатель данных! хочешь при...
# 7  Полная занятость  ищем senior\middle+ data scientist в команду s...
# 8  Полная занятость  мтс финтех – одно из ключевых направлений разв...
# 9  Полная занятость  интерлизинг – федеральная лизинговая компания ...
#
#                               description_lemmatized  salary_from  salary_to  \
# 0  sberseasons оплачивать программа стажировка ра...          NaN        NaN
# 1  бюро кредитный история скоринг бюро являться к...          NaN        NaN
# 2  компания команда группа компания фск многопроф...          NaN        NaN
# 3  наш команда разрабатывать модель машинный обуч...          NaN        NaN
# 4  искать талантливый middle data analyst data sc...     350000.0        NaN
# 5  обязанность собирать данные dwh экспериментиро...     300000.0   450000.0
# 6  привет будущий заклинатель данные хотеть присо...          NaN        NaN
# 7  искать senior middle data scientist команда sb...          NaN        NaN
# 8  мтс финтех ключевой направление развитие групп...          NaN        NaN
# 9  интерлизинг федеральный лизинговый компания 24...          NaN        NaN
#
#          salary_bin                   key_skills_from_key_skills_field  \
# 0     ЗП не указана                                                NaN
# 1     ЗП не указана  SQL, MS SQL, Big Data, Python, Spark, Hadoop, ...
# 2     ЗП не указана  Python, PyTorch, ML, Docker, NLP, Pandas, SQL,...
# 3     ЗП не указана                                                NaN
# 4     ЗП не указана  Python, SQL, Обучение и развитие, Data Mining,...
# 5  Больше 300 тысяч  ml, Python, numpy, scipy, pandas, sklearn, Cli...
# 6     ЗП не указана       Python, Big Data, SQL, Machine Learning, Git
# 7     ЗП не указана                                                NaN
# 8     ЗП не указана                                        Python, SQL
# 9     ЗП не указана  Python, Big Data, Работа с базами данных, Стат...
#
#   hard_skills_from_description          soft_skills_from_description
# 0                          NaN                                   NaN
# 1                       Pandas  Документация, Аналитическое мышление
# 2                          NaN                                   NaN
# 3                          NaN                                   NaN
# 4                          NaN                Аналитическое мышление
# 5                       Pandas                          Документация
# 6                       Pandas                                   NaN
# 7                          NaN                                   NaN
# 8                          NaN                          Документация
# 9                          NaN                          Документация

# %% [markdown]
# **Вывод по разделу 1**
#
# Загрузка данных выполнена успешна

# %% [markdown]
# ## 2. Выполнение предобработки данных

# %%
data_ds_f.info() # выводим побщую информацию о данных для таблицы с вканасиями дата сайнтистов
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 974 entries, 0 to 973
# Data columns (total 20 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                974 non-null    int64
#  1   name                              974 non-null    object
#  2   published_at                      974 non-null    datetime64[ns]
#  3   alternate_url                     974 non-null    object
#  4   type                              974 non-null    object
#  5   employer                          974 non-null    object
#  6   department                        413 non-null    object
#  7   area                              974 non-null    object
#  8   experience                        974 non-null    object
#  9   key_skills                        974 non-null    object
#  10  schedule                          974 non-null    object
#  11  employment                        974 non-null    object
#  12  description                       974 non-null    object
#  13  description_lemmatized            974 non-null    object
#  14  salary_from                       88 non-null     float64
#  15  salary_to                         82 non-null     float64
#  16  salary_bin                        974 non-null    object
#  17  key_skills_from_key_skills_field  521 non-null    object
#  18  hard_skills_from_description      449 non-null    object
#  19  soft_skills_from_description      294 non-null    object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(16)
# memory usage: 152.3+ KB

# %%
data_da_f.info()# выводим побщую информацию о данных для таблицы с вканасиями дата аналитиков
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1801 entries, 0 to 1800
# Data columns (total 20 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                1801 non-null   int64
#  1   name                              1801 non-null   object
#  2   published_at                      1801 non-null   datetime64[ns]
#  3   alternate_url                     1801 non-null   object
#  4   type                              1801 non-null   object
#  5   employer                          1801 non-null   object
#  6   department                        521 non-null    object
#  7   area                              1801 non-null   object
#  8   experience                        1801 non-null   object
#  9   key_skills                        1801 non-null   object
#  10  schedule                          1801 non-null   object
#  11  employment                        1801 non-null   object
#  12  description                       1801 non-null   object
#  13  description_lemmatized            1801 non-null   object
#  14  salary_from                       348 non-null    float64
#  15  salary_to                         228 non-null    float64
#  16  salary_bin                        1801 non-null   object
#  17  key_skills_from_key_skills_field  1093 non-null   object
#  18  hard_skills_from_description      418 non-null    object
#  19  soft_skills_from_description      588 non-null    object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(16)
# memory usage: 281.5+ KB

# %% [markdown]
# ### 2.1 Ищем пропуски в данных

# %%
data_da_f.isna().sum() # считаем пропуски в данных
# Out:
# id                                     0
# name                                   0
# published_at                           0
# alternate_url                          0
# type                                   0
# employer                               0
# department                          1280
# area                                   0
# experience                             0
# key_skills                             0
# schedule                               0
# employment                             0
# description                            0
# description_lemmatized                 0
# salary_from                         1453
# salary_to                           1573
# salary_bin                             0
# key_skills_from_key_skills_field     708
# hard_skills_from_description        1383
# soft_skills_from_description        1213
# dtype: int64

# %%
data_ds_f.isna().sum()# считаем пропуски в данных
# Out:
# id                                    0
# name                                  0
# published_at                          0
# alternate_url                         0
# type                                  0
# employer                              0
# department                          561
# area                                  0
# experience                            0
# key_skills                            0
# schedule                              0
# employment                            0
# description                           0
# description_lemmatized                0
# salary_from                         886
# salary_to                           892
# salary_bin                            0
# key_skills_from_key_skills_field    453
# hard_skills_from_description        525
# soft_skills_from_description        680
# dtype: int64

# %% [markdown]
# **Вывод по разделу 2.1**
#
# Критичные пропуски выявлены в столбцах с зарплатой, замена будет выполнена в следующих разделах

# %% [markdown]
# ### 2.2 Ищем дубликаты

# %%
# ищем дубликаты
data_da_f[data_da_f.duplicated(['employer', 'name','key_skills','description'], keep=False)]
# Out:
#              id                                               name  \
# 3     100046788                            Ведущий аналитик данных
# 6     100060772                                    Аналитик данных
# 7     100069131                                      Дата аналитик
# 13    100080293                     Data analyst / Аналитик данных
# 14    100082545     Аналитик данных (Отдел по анализу конкурентов)
# ...         ...                                                ...
# 1796   99985864  Аналитик данных в отдел онлайн-маркетинга (мон...
# 1797   99986822                   Аналитик данных/специалист Excel
# 1798   99988999  Аналитик данных на производстве \ Data Analyst...
# 1799   99989203  Аналитик данных на производстве \ Data Analyst...
# 1800   99989339  Аналитик данных на производстве \ Data Analyst...
#
#             published_at                    alternate_url      type  \
# 3    2024-05-24 10:28:18  https://hh.ru/vacancy/100046788  Открытая
# 6    2024-05-24 11:56:20  https://hh.ru/vacancy/100060772  Открытая
# 7    2024-05-24 13:05:01  https://hh.ru/vacancy/100069131  Открытая
# 13   2024-05-24 14:36:52  https://hh.ru/vacancy/100080293  Открытая
# 14   2024-06-05 11:38:18  https://hh.ru/vacancy/100082545  Открытая
# ...                  ...                              ...       ...
# 1796 2024-05-23 18:41:27   https://hh.ru/vacancy/99985864  Открытая
# 1797 2024-06-10 18:58:20   https://hh.ru/vacancy/99986822  Открытая
# 1798 2024-05-23 19:35:56   https://hh.ru/vacancy/99988999  Открытая
# 1799 2024-05-23 19:40:04   https://hh.ru/vacancy/99989203  Открытая
# 1800 2024-05-23 19:41:22   https://hh.ru/vacancy/99989339  Открытая
#
#                                          employer                  department  \
# 3                                        Х5 Group  X5 GROUP, Центральный офис
# 6     ГКУ Центр занятости населения города Москвы                         NaN
# 7                                            СБЕР          Сбер для экспертов
# 13                                  Колл Солюшенс                         NaN
# 14                                           Ozon       Ozon Офис и Коммерция
# ...                                           ...                         ...
# 1796                                 Леруа Мерлен                          ИТ
# 1797                                    СКАЙ БОНД                         NaN
# 1798                                         Марс                         NaN
# 1799                                         Марс                         NaN
# 1800                                         Марс                         NaN
#
#                  area           experience  \
# 3              Москва  Junior+ (1-3 years)
# 6              Москва  Junior+ (1-3 years)
# 7     Санкт-Петербург  Junior+ (1-3 years)
# 13    Санкт-Петербург   Middle (3-6 years)
# 14             Москва  Junior+ (1-3 years)
# ...               ...                  ...
# 1796           Москва  Junior+ (1-3 years)
# 1797  Санкт-Петербург  Junior+ (1-3 years)
# 1798          Ступино  Junior+ (1-3 years)
# 1799         Одинцово  Junior+ (1-3 years)
# 1800        Ульяновск  Junior+ (1-3 years)
#
#                                              key_skills          schedule  \
# 3     ['Анализ данных', 'Коммуникация', 'SQL', 'MS O...       Полный день
# 6                                                    []       Полный день
# 7     ['Документация', 'Проактивность', 'Коммуникация']       Полный день
# 13    ['Анализ данных', 'Проактивность', 'SQL', 'Pyt...       Полный день
# 14                                                   []       Полный день
# ...                                                 ...               ...
# 1796  ['Проактивность', 'Коммуникация', 'SQL', 'ad-h...     Гибкий график
# 1797  ['Грамотная речь', 'Сводные таблицы', 'Сбор и ...  Удаленная работа
# 1798  ['Анализ данных', 'SQL', 'MS Power BI', 'Pytho...     Гибкий график
# 1799  ['Анализ данных', 'SQL', 'MS Power BI', 'Pytho...       Полный день
# 1800  ['Анализ данных', 'SQL', 'MS Power BI', 'Pytho...       Полный день
#
#             employment                                        description  \
# 3     Полная занятость  задачи:  разработка бизнес-моделей для группов...
# 6     Полная занятость  один из ключевых партнеров центра занятости на...
# 7     Полная занятость  команда данных по инвестиционным продуктам. мы...
# 13    Полная занятость  обязанности:   исследование поведения пользова...
# 14    Полная занятость  вам предстоит:   осуществлять многофакторный а...
# ...                ...                                                ...
# 1796  Полная занятость  леруа мерлен — data-driven компания с передовы...
# 1797  Полная занятость  sky bond – это агентство финансовых консультан...
# 1798  Полная занятость  аналитик будет заниматься сбором, обработкой, ...
# 1799  Полная занятость  аналитик будет заниматься сбором, обработкой, ...
# 1800  Полная занятость  аналитик будет заниматься сбором, обработкой, ...
#
#                                  description_lemmatized  salary_from  \
# 3     задача разработка бизнес модель групповой прог...          NaN
# 6     ключевой партнер центр занятость население раб...     100000.0
# 7     команда данные инвестиционный продукт развиват...          NaN
# 13    обязанность исследование поведение пользовател...          NaN
# 14    предстоять осуществлять многофакторный анализ ...          NaN
# ...                                                 ...          ...
# 1796  леруа мерлен data driven компания передовой ит...          NaN
# 1797  sky bond агентство финансовый консультант евро...      50000.0
# 1798  аналитик заниматься сбор обработка изучение ан...          NaN
# 1799  аналитик заниматься сбор обработка изучение ан...          NaN
# 1800  аналитик заниматься сбор обработка изучение ан...          NaN
#
#       salary_to     salary_bin  \
# 3           NaN  ЗП не указана
# 6           NaN  ЗП не указана
# 7           NaN  ЗП не указана
# 13          NaN  ЗП не указана
# 14          NaN  ЗП не указана
# ...         ...            ...
# 1796        NaN  ЗП не указана
# 1797        NaN  ЗП не указана
# 1798        NaN  ЗП не указана
# 1799        NaN  ЗП не указана
# 1800        NaN  ЗП не указана
#
#                        key_skills_from_key_skills_field  \
# 3     MS Office, SQL, Python, Hadoop, Нive, Аналитич...
# 6                                                   NaN
# 7                                                   NaN
# 13    SQL, Python, Airflow, Анализ данных, Базы данн...
# 14                                                  NaN
# ...                                                 ...
# 1796  SQL, ad-hoc, A/B тесты, ETL, LTV, Python, Post...
# 1797  Пользователь ПК, Работа в команде, Грамотная р...
# 1798  MS Power BI, Аналитика, Python, SQL, Tableau, ...
# 1799  MS Power BI, Аналитика, Python, SQL, Tableau, ...
# 1800  MS Power BI, Аналитика, Python, SQL, Tableau, ...
#
#      hard_skills_from_description               soft_skills_from_description
# 3          Pandas, Юнит-экономика                               Коммуникация
# 6                             NaN                                        NaN
# 7                             NaN  Коммуникация, Документация, Проактивность
# 13                            NaN                              Проактивность
# 14                            NaN                                        NaN
# ...                           ...                                        ...
# 1796                          NaN                Коммуникация, Проактивность
# 1797                          NaN                                        NaN
# 1798                          NaN                                        NaN
# 1799                          NaN                                        NaN
# 1800                          NaN                                        NaN
#
# [531 rows x 20 columns]

# %%
# ищем дубликаты
data_ds_f[data_ds_f.duplicated(['employer', 'name','key_skills','description'], keep=False)]
# Out:
#             id                                               name  \
# 2    100070495                       ML Engineer / Data Scientist
# 3    100076648                             Team Lead Data Science
# 7    100094269                 Middle/Senior Data Scientist (LLM)
# 10   100293732    Cпециалист по работе с данными (Data Scientist)
# 11   100296110                      Эконометрист / Data scientist
# ..         ...                                                ...
# 964   99925786                        Junior Data Scientist (NLP)
# 965   99925787                        Junior Data Scientist (NLP)
# 966   99925788                        Junior Data Scientist (NLP)
# 967   99925789                        Junior Data Scientist (NLP)
# 973   99973974  Middle/Senior Data Scientist (блок Управление ...
#
#            published_at                    alternate_url      type  \
# 2   2024-05-24 13:15:26  https://hh.ru/vacancy/100070495  Открытая
# 3   2024-05-24 14:07:00  https://hh.ru/vacancy/100076648  Открытая
# 7   2024-05-24 16:33:00  https://hh.ru/vacancy/100094269  Открытая
# 10  2024-06-10 11:49:46  https://hh.ru/vacancy/100293732  Открытая
# 11  2024-05-27 08:31:02  https://hh.ru/vacancy/100296110  Открытая
# ..                  ...                              ...       ...
# 964 2024-05-23 10:06:18   https://hh.ru/vacancy/99925786  Открытая
# 965 2024-05-23 10:06:18   https://hh.ru/vacancy/99925787  Открытая
# 966 2024-05-23 10:06:18   https://hh.ru/vacancy/99925788  Открытая
# 967 2024-05-23 10:06:18   https://hh.ru/vacancy/99925789  Открытая
# 973 2024-05-23 16:29:00   https://hh.ru/vacancy/99973974  Открытая
#
#          employer          department             area             experience  \
# 2          ГК ФСК                 NaN           Москва    Junior+ (1-3 years)
# 3            СБЕР  Сбер для экспертов           Москва     Middle (3-6 years)
# 7            СБЕР  Сбер для экспертов           Москва     Middle (3-6 years)
# 10   Открытый код                 NaN           Самара    Junior+ (1-3 years)
# 11          Okkam                 NaN           Москва     Middle (3-6 years)
# ..            ...                 ...              ...                    ...
# 964        Молвер                 NaN  Санкт-Петербург  Junior (no experince)
# 965        Молвер                 NaN     Екатеринбург  Junior (no experince)
# 966        Молвер                 NaN      Новосибирск  Junior (no experince)
# 967        Молвер                 NaN           Казань  Junior (no experince)
# 973          СБЕР  Сбер для экспертов           Москва     Middle (3-6 years)
#
#                                             key_skills          schedule  \
# 2    ['Python', 'PyTorch', 'Machine Learning', 'Doc...       Полный день
# 3                                                   []       Полный день
# 7                                                   []       Полный день
# 10                                          ['Pandas']       Полный день
# 11                          ['Pandas', 'Коммуникация']       Полный день
# ..                                                 ...               ...
# 964  ['Python', 'Data Mining', 'Математическая стат...  Удаленная работа
# 965  ['Python', 'Data Mining', 'Математическая стат...  Удаленная работа
# 966  ['Python', 'Data Mining', 'Математическая стат...  Удаленная работа
# 967  ['Python', 'Data Mining', 'Математическая стат...  Удаленная работа
# 973  ['Pandas', 'Документация', 'Аналитическое мышл...       Полный день
#
#            employment                                        description  \
# 2    Полная занятость  о компании и команде: группа компаний фск – мн...
# 3    Полная занятость  наша команда разрабатывает модели машинного об...
# 7    Полная занятость  ищем senior\middle+ data scientist в команду s...
# 10   Полная занятость  что нужно делать:  анализ исходных данных, очи...
# 11   Полная занятость  привет!мы - коммуникационная группа okkam. наш...
# ..                ...                                                ...
# 964  Полная занятость  мы– это новый технологический продукт в сфере ...
# 965  Полная занятость  мы– это новый технологический продукт в сфере ...
# 966  Полная занятость  мы– это новый технологический продукт в сфере ...
# 967  Полная занятость  мы– это новый технологический продукт в сфере ...
# 973  Полная занятость  в нашей команде вы получите возможность работа...
#
#                                 description_lemmatized  salary_from  \
# 2    компания команда группа компания фск многопроф...          NaN
# 3    наш команда разрабатывать модель машинный обуч...          NaN
# 7    искать senior middle data scientist команда sb...          NaN
# 10   нужно делать анализ исходный данные очистка ау...          NaN
# 11   привет коммуникационный группа okkam наш специ...          NaN
# ..                                                 ...          ...
# 964  новый технологический продукт сфера ия наш роб...      60000.0
# 965  новый технологический продукт сфера ия наш роб...      60000.0
# 966  новый технологический продукт сфера ия наш роб...      60000.0
# 967  новый технологический продукт сфера ия наш роб...      60000.0
# 973  наш команда получать возможность работать созд...          NaN
#
#      salary_to     salary_bin  \
# 2          NaN  ЗП не указана
# 3          NaN  ЗП не указана
# 7          NaN  ЗП не указана
# 10         NaN  ЗП не указана
# 11         NaN  ЗП не указана
# ..         ...            ...
# 964        NaN  ЗП не указана
# 965        NaN  ЗП не указана
# 966        NaN  ЗП не указана
# 967        NaN  ЗП не указана
# 973        NaN  ЗП не указана
#
#                       key_skills_from_key_skills_field  \
# 2    Python, PyTorch, ML, Docker, NLP, Pandas, SQL,...
# 3                                                  NaN
# 7                                                  NaN
# 10                                                 NaN
# 11                                                 NaN
# ..                                                 ...
# 964  Python, Математическая статистика, Git, Data M...
# 965  Python, Математическая статистика, Git, Data M...
# 966  Python, Математическая статистика, Git, Data M...
# 967  Python, Математическая статистика, Git, Data M...
# 973                                                NaN
#
#     hard_skills_from_description          soft_skills_from_description
# 2                            NaN                                   NaN
# 3                            NaN                                   NaN
# 7                            NaN                                   NaN
# 10                        Pandas                                   NaN
# 11                        Pandas                          Коммуникация
# ..                           ...                                   ...
# 964                          NaN                                   NaN
# 965                          NaN                                   NaN
# 966                          NaN                                   NaN
# 967                          NaN                                   NaN
# 973                       Pandas  Документация, Аналитическое мышление
#
# [333 rows x 20 columns]

# %% [markdown]
# **Вывод по разделу 2.2**
#
# Явных дубликатов не выявлено.
# В целом выявлены вакансий, в которых полностью совпадают значения в полях `employer`, `name`, `key_skills`, `dscription`.
# При этом существуют различия в дате публикации, что целом говорит о том, что выявленные строки не являются дубликатами, так как вакансии могли быть опубликованы повторно, по причинам необъходимости найма новых сотрудников с аналогичными требованиями

# %% [markdown]
# Дополнительно определим минимальную и максимальную даты датасета и ограничили выборку период с 01.03.2024 по 31.05.2024

# %%
min_data = data_da_f['published_at'].min()
min_data
# Out:
# Timestamp('2024-02-13 21:45:51')

# %%
max_data = data_da_f['published_at'].max()
max_data
# Out:
# Timestamp('2024-06-11 15:07:30')

# %%
min_data_ds = data_ds_f['published_at'].min()
min_data_ds
# Out:
# Timestamp('2024-02-29 15:01:35')

# %%
max_data_ds = data_ds_f['published_at'].max()
max_data_ds
# Out:
# Timestamp('2024-06-11 12:49:09')

# %%
# меняем формат данных 
data_da_f['published_at']=pd.to_datetime(data_da_f['published_at'])

# %%
# меняем формат данных 
data_ds_f['published_at']=pd.to_datetime(data_ds_f['published_at'])

# %%
# ограничиваем массив данных периодом с марта по май 2024
data_da = data_da_f.query('published_at>="2024-03-01 00:00:00" and published_at <= "2024-05-31 23:59:59"')

# %%
# ограничиваем массив данных периодом с марта по май 2024
data_ds = data_ds_f.query('published_at>="2024-03-01 00:00:00" and published_at <= "2024-05-31 23:59:59"')

# %% [markdown]
# ## 3. Исследовательский анализ данных.

# %% [markdown]
# ### 3.1 Выявление грейда требуемых специалистов по названию вакансии или по колонке с требуемым опытом.

# %%
data_da.groupby('name')['id'].count() # группируем данные по названию вакансий
# Out:
# name
# Antifraud / data analyst                                                   1
# BI аналитик / аналитик данных (сквозная, web - аналитика, визуализация)    1
# BI-analyst \ Data analyst \ Аналитик данных (Senior)                       1
# BI-Аналитик/Бизнес-Аналитик/Аналитик данных                                1
# BI-аналитик / Data Analyst / Аналитик данных                               1
#                                                                           ..
# Финансовый аналитик / Аналитик данных                                      1
# Финансовый аналитик данных                                                 1
# Финансовый аналитик/ Data Analyst / Data scientist                         1
# Эксперт по цифровым технологиям аудита (Data Analyst)                      2
# Эксперт-аналитик данных в группу цифрового аудита                          2
# Name: id, Length: 627, dtype: int64

# %%
data_da.loc[:,'name']=data_da['name'].str.lower() # названия вакансий приводит к нижнему регистру

# %%
# Определяем фразы для поиска
phrases = ['аналитик данных', 'data analyst', 'дата аналитик']

# Функция для удаления всего до и после фраз
def extract_phrase(text, phrases):
    for phrase in phrases:
        if phrase in text:
            return phrase
    return 0

# %%
# Создаем новый столбец, содержащий только указанные фразы
data_da.loc[:,'vac_name'] = data_da['name'].apply(lambda x: extract_phrase(x, phrases))

# %%
# Выводим результат
data_da.head(5)
# Out:
#           id                                    name        published_at  \
# 0  100039284  junior аналитик данных (исследователь) 2024-05-24 09:37:04
# 1  100039480                         аналитик данных 2024-05-24 09:39:00
# 2  100042705         аналитик данных (исследователь) 2024-05-24 10:01:25
# 3  100046788                 ведущий аналитик данных 2024-05-24 10:28:18
# 4  100056244                         аналитик данных 2024-05-24 11:27:40
#
#                      alternate_url      type           employer  \
# 0  https://hh.ru/vacancy/100039284  Открытая  DNS Головной офис
# 1  https://hh.ru/vacancy/100039480  Открытая              Комус
# 2  https://hh.ru/vacancy/100042705  Открытая  DNS Головной офис
# 3  https://hh.ru/vacancy/100046788  Открытая           Х5 Group
# 4  https://hh.ru/vacancy/100056244  Открытая             ЛУКОЙЛ
#
#                    department         area             experience  \
# 0                         NaN  Владивосток  Junior (no experince)
# 1                         NaN       Москва  Junior (no experince)
# 2                         NaN  Владивосток    Junior+ (1-3 years)
# 3  X5 GROUP, Центральный офис       Москва    Junior+ (1-3 years)
# 4                         NaN       Москва     Middle (3-6 years)
#
#                                           key_skills  ...  \
# 0              ['Power BI', 'СУБД', 'Python', 'SQL']  ...
# 1   ['MS SQL', 'Работа с базами данных', 'MS Excel']  ...
# 2  ['SQL', 'Power BI', 'СУБД', 'Python', 'Clickho...  ...
# 3  ['Анализ данных', 'Коммуникация', 'SQL', 'MS O...  ...
# 4                                   ['Документация']  ...
#
#                                          description  \
# 0  наше направление занимается повышением эффекти...
# 1  сегодня комус один из крупнейших поставщиков о...
# 2  наше направление занимается повышением эффекти...
# 3  задачи:  разработка бизнес-моделей для группов...
# 4  обязанности:  участие в проектировании, разраб...
#
#                               description_lemmatized salary_from salary_to  \
# 0  наш направление заниматься повышение эффективн...     60000.0       NaN
# 1  сегодня комус крупный поставщик офисный товар ...         NaN       NaN
# 2  наш направление заниматься повышение эффективн...     90000.0       NaN
# 3  задача разработка бизнес модель групповой прог...         NaN       NaN
# 4  обязанность участие проектирование разработка ...         NaN       NaN
#
#       salary_bin                   key_skills_from_key_skills_field  \
# 0  ЗП не указана                        SQL, Power BI, Python, СУБД
# 1  ЗП не указана           Работа с базами данных, MS SQL, MS Excel
# 2  ЗП не указана      SQL, Power BI, Python, СУБД, BPMN, Clickhouse
# 3  ЗП не указана  MS Office, SQL, Python, Hadoop, Нive, Аналитич...
# 4  ЗП не указана                                                NaN
#
#   hard_skills_from_description soft_skills_from_description         vac_name  \
# 0                          NaN                          NaN  аналитик данных
# 1                          NaN                          NaN  аналитик данных
# 2                          NaN                          NaN  аналитик данных
# 3       Pandas, Юнит-экономика                 Коммуникация  аналитик данных
# 4                          NaN                 Документация  аналитик данных
#
#   month
# 0     5
# 1     5
# 2     5
# 3     5
# 4     5
#
# [5 rows x 22 columns]

# %%
data_da['vac_name'].isnull().count() # проверяем, что все строки в столбце vac_name заполнены данными
# Out:
# 1410

# %%
data_da.loc[:,'vac_name'] = data_da['vac_name'].str.replace('data analyst','аналитик данных') #  делаем замену значений в стоблце vac_name

# %%
data_da.loc[:,'vac_name'] = data_da['vac_name'].str.replace('дата аналитик','аналитик данных') #  делаем замену значений в стоблце vac_name

# %%
name_grouped = data_da.groupby('experience')['id'].count().reset_index().sort_values(by='id', ascending=False) # группируем данные для расчета количества вакансий в разбивке по грейдам
name_grouped
# Out:
#               experience   id
# 1    Junior+ (1-3 years)  850
# 2     Middle (3-6 years)  442
# 0  Junior (no experince)  108
# 3      Senior (6+ years)   10

# %%
name_grouped = name_grouped.rename(columns ={'id':'vacancy_count'}) # переименовываем колонку
name_grouped
# Out:
#               experience  vacancy_count
# 1    Junior+ (1-3 years)            850
# 2     Middle (3-6 years)            442
# 0  Junior (no experince)            108
# 3      Senior (6+ years)             10

# %%
name_grouped['ratio,%'] = (round(name_grouped['vacancy_count']/name_grouped['vacancy_count'].sum(),2))*100 # считаем долю вакансий по грейдам
name_grouped
# Out:
#               experience  vacancy_count  ratio,%
# 1    Junior+ (1-3 years)            850     60.0
# 2     Middle (3-6 years)            442     31.0
# 0  Junior (no experince)            108      8.0
# 3      Senior (6+ years)             10      1.0

# %% [markdown]
# #### Повторяем действия для датафрейма с вакансиями data scientist

# %%
data_ds.groupby('name')['id'].count() # группируем данные по названию вакансий
# Out:
# name
# assistant professor - data science&ai (english)                            1
# associate professor - data science&ai (english)                            2
# computer vision engineer \ data scientist в команду layer, sberdevices.    2
# cпециалист по работе с данными (data scientist)                            1
# data analyst (data science и клиентская аналитика)                         2
#                                                                           ..
# эконометрист / data scientist                                              3
# эксперт data science                                                       2
# эксперт data science в направление андеррайтинг                            1
# эксперт группа аналитики и моделирования (data scientist)                  1
# эксперт по моделированию и анализу данных / data scientist                 1
# Name: id, Length: 379, dtype: int64

# %%
data_ds.loc[:,'name']=data_ds['name'].str.lower()  # названия вакансий приводим к нижнему регистру

# %%
# Определяем фразы для поиска
phrases_ds = ['data scientist', 'data science']

# %%
# Создаем новый столбец, содержащий только указанные фразы
data_ds.loc[:,'vac_name'] = data_ds['name'].apply(lambda x: extract_phrase(x, phrases_ds))
data_ds.head(5) # Выводим результат
# Out:
#           id                               name        published_at  \
# 0  100049339  стажер data science (новосибирск) 2024-05-24 09:37:04
# 1  100051447                     data scientist 2024-05-24 09:39:00
# 2  100070495       ml engineer / data scientist 2024-05-24 10:01:25
# 3  100076648             team lead data science 2024-05-24 10:28:18
# 6  100088790                     data scientist 2024-05-24 11:56:20
#
#                      alternate_url      type  \
# 0  https://hh.ru/vacancy/100049339  Открытая
# 1  https://hh.ru/vacancy/100051447  Открытая
# 2  https://hh.ru/vacancy/100070495  Открытая
# 3  https://hh.ru/vacancy/100076648  Открытая
# 6  https://hh.ru/vacancy/100088790  Открытая
#
#                               employer          department             area  \
# 0                                 СБЕР  Сбер для экспертов      Новосибирск
# 1  Бюро кредитных историй Скоринг Бюро                 NaN           Москва
# 2                               ГК ФСК                 NaN           Москва
# 3                                 СБЕР  Сбер для экспертов           Москва
# 6                           Ростелеком                 NaN  Санкт-Петербург
#
#               experience                                         key_skills  \
# 0  Junior (no experince)                                                 []
# 1    Junior+ (1-3 years)  ['Python', 'Hadoop', 'Machine Learning', 'Рабо...
# 2    Junior+ (1-3 years)  ['Python', 'PyTorch', 'Machine Learning', 'Doc...
# 3     Middle (3-6 years)                                                 []
# 6    Junior+ (1-3 years)  ['Python', 'Machine Learning', 'SQL', 'Big Dat...
#
#    ...                                        description  \
# 0  ...  sberseasons - оплачиваемая программа стажирово...
# 1  ...  бюро кредитных историй «скоринг бюро» является...
# 2  ...  о компании и команде: группа компаний фск – мн...
# 3  ...  наша команда разрабатывает модели машинного об...
# 6  ...  привет, будущий заклинатель данных! хочешь при...
#
#                               description_lemmatized salary_from salary_to  \
# 0  sberseasons оплачивать программа стажировка ра...         NaN       NaN
# 1  бюро кредитный история скоринг бюро являться к...         NaN       NaN
# 2  компания команда группа компания фск многопроф...         NaN       NaN
# 3  наш команда разрабатывать модель машинный обуч...         NaN       NaN
# 6  привет будущий заклинатель данные хотеть присо...         NaN       NaN
#
#       salary_bin                   key_skills_from_key_skills_field  \
# 0  ЗП не указана                                                NaN
# 1  ЗП не указана  SQL, MS SQL, Big Data, Python, Spark, Hadoop, ...
# 2  ЗП не указана  Python, PyTorch, ML, Docker, NLP, Pandas, SQL,...
# 3  ЗП не указана                                                NaN
# 6  ЗП не указана       Python, Big Data, SQL, Machine Learning, Git
#
#   hard_skills_from_description          soft_skills_from_description  \
# 0                          NaN                                   NaN
# 1                       Pandas  Документация, Аналитическое мышление
# 2                          NaN                                   NaN
# 3                          NaN                                   NaN
# 6                       Pandas                                   NaN
#
#          vac_name month
# 0    data science     5
# 1  data scientist     5
# 2  data scientist     5
# 3    data science     5
# 6  data scientist     5
#
# [5 rows x 22 columns]

# %%
data_ds.loc[:,'vac_name'] = data_ds['vac_name'].str.replace('data science','data scientist') #  делаем замену значений в стоблце vac_name

# %%
name_grouped_ds = data_ds.groupby('experience')['id'].count().reset_index().sort_values(by='id', ascending=False) # группируем данные для расчета количества вакансий в разбивке по грейдам
name_grouped_ds
# Out:
#               experience   id
# 2     Middle (3-6 years)  357
# 1    Junior+ (1-3 years)  334
# 0  Junior (no experince)   37
# 3      Senior (6+ years)   24

# %%
name_grouped_ds = name_grouped_ds.rename(columns ={'id':'vacancy_count'}) # переименовываем столбец
name_grouped_ds
# Out:
#               experience  vacancy_count
# 2     Middle (3-6 years)            357
# 1    Junior+ (1-3 years)            334
# 0  Junior (no experince)             37
# 3      Senior (6+ years)             24

# %%
name_grouped_ds['ratio,%'] = (round(name_grouped_ds['vacancy_count']/name_grouped_ds['vacancy_count'].sum(),2))*100 # считаем долю вакансий по грейдам
name_grouped_ds
# Out:
#               experience  vacancy_count  ratio,%
# 2     Middle (3-6 years)            357     47.0
# 1    Junior+ (1-3 years)            334     44.0
# 0  Junior (no experince)             37      5.0
# 3      Senior (6+ years)             24      3.0

# %%
data = pd.concat([data_da,data_ds], ignore_index=True) # соединяем 2 таблицы

# %%
a=data[data['vac_name'].isnull()] # проверка, что все поля в столбце vac_name заполнены
a
# Out:
# Empty DataFrame
# Columns: [id, name, published_at, alternate_url, type, employer, department, area, experience, key_skills, schedule, employment, description, description_lemmatized, salary_from, salary_to, salary_bin, key_skills_from_key_skills_field, hard_skills_from_description, soft_skills_from_description, vac_name, month]
# Index: []
#
# [0 rows x 22 columns]

# %%
a['name'].unique() # проверка
# Out:
# array([], dtype=object)

# %%
# Данные для первой таблицы
labels1 = name_grouped['experience']
sizes1 = name_grouped['ratio,%']
colors1 = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue']
explode1 = (0.1, 0, 0, 0)  # Выделим первый кусок (Junior)

# Данные для второй таблицы
labels2 = name_grouped_ds['experience']
sizes2 = name_grouped_ds['ratio,%']
colors2 = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue']
explode2 = (0.1, 0, 0, 0)  # Выделим первый кусок (Junior)

# Создание диаграмм
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 7))

ax1.pie(sizes1, explode=explode1, labels=labels1, colors=colors1, autopct='%1.1f%%', shadow=True, startangle=140)
ax1.set_title('Распределение по опыту работы для вакансий "Аналитик данных"')

ax2.pie(sizes2, explode=explode2, labels=labels2, colors=colors2, autopct='%1.1f%%', shadow=True, startangle=140)
ax2.set_title('Распределение по опыту работы для вакансий "Data Scientist"')

plt.show()

# %% [markdown]
# **Вывод по разделу 3.1**
#
# На основании графиков мы видим, что для вакансий "Аналитик данных" требуется большего всего специалистов грейда Junior+ (1-3 years),  а именно 60%.
# При этом для вакансий "Data Scientist" большего всего требуется специалистов грейда Middle (3-6 years), а именно 47,5%. На втором месте по необходимости для вакансий "Data Scientist" специалисты грейда Junior+ (1-3 years), таких вакансий 44,4%

# %% [markdown]
# ### 3.2 Определение типичного места работы для Аналитика данных и Бизнес-аналитика по следующим параметрам: ТОП-работодателей по числу вакансий, зарплата, тип занятости, график работы.

# %% [markdown]
# #### 3.2.1 ТОП-работодателей по числу вакансий

# %%
data_da.loc[:,'published_at']=pd.to_datetime(data_da['published_at']) # перерводим значения в столбце нужному формату

# %%
data_da.loc[:,'month']=data['published_at'].dt.month # выделяем столбец с месяцем публикации вакансии

# %%
data_ds.loc[:,'published_at']=pd.to_datetime(data_da['published_at']) # перерводим значения в столбце нужному формату

# %%
data_ds.loc[:,'month']=data['published_at'].dt.month # выделяем столбец с месяцем публикации вакансии

# %%
data_da.head(5) # выводим первые 5 строк датафрейма
# Out:
#           id                                    name        published_at  \
# 0  100039284  junior аналитик данных (исследователь) 2024-05-24 09:37:04
# 1  100039480                         аналитик данных 2024-05-24 09:39:00
# 2  100042705         аналитик данных (исследователь) 2024-05-24 10:01:25
# 3  100046788                 ведущий аналитик данных 2024-05-24 10:28:18
# 4  100056244                         аналитик данных 2024-05-24 11:27:40
#
#                      alternate_url      type           employer  \
# 0  https://hh.ru/vacancy/100039284  Открытая  DNS Головной офис
# 1  https://hh.ru/vacancy/100039480  Открытая              Комус
# 2  https://hh.ru/vacancy/100042705  Открытая  DNS Головной офис
# 3  https://hh.ru/vacancy/100046788  Открытая           Х5 Group
# 4  https://hh.ru/vacancy/100056244  Открытая             ЛУКОЙЛ
#
#                    department         area             experience  \
# 0                         NaN  Владивосток  Junior (no experince)
# 1                         NaN       Москва  Junior (no experince)
# 2                         NaN  Владивосток    Junior+ (1-3 years)
# 3  X5 GROUP, Центральный офис       Москва    Junior+ (1-3 years)
# 4                         NaN       Москва     Middle (3-6 years)
#
#                                           key_skills  ...  \
# 0              ['Power BI', 'СУБД', 'Python', 'SQL']  ...
# 1   ['MS SQL', 'Работа с базами данных', 'MS Excel']  ...
# 2  ['SQL', 'Power BI', 'СУБД', 'Python', 'Clickho...  ...
# 3  ['Анализ данных', 'Коммуникация', 'SQL', 'MS O...  ...
# 4                                   ['Документация']  ...
#
#                                          description  \
# 0  наше направление занимается повышением эффекти...
# 1  сегодня комус один из крупнейших поставщиков о...
# 2  наше направление занимается повышением эффекти...
# 3  задачи:  разработка бизнес-моделей для группов...
# 4  обязанности:  участие в проектировании, разраб...
#
#                               description_lemmatized salary_from salary_to  \
# 0  наш направление заниматься повышение эффективн...     60000.0       NaN
# 1  сегодня комус крупный поставщик офисный товар ...         NaN       NaN
# 2  наш направление заниматься повышение эффективн...     90000.0       NaN
# 3  задача разработка бизнес модель групповой прог...         NaN       NaN
# 4  обязанность участие проектирование разработка ...         NaN       NaN
#
#       salary_bin                   key_skills_from_key_skills_field  \
# 0  ЗП не указана                        SQL, Power BI, Python, СУБД
# 1  ЗП не указана           Работа с базами данных, MS SQL, MS Excel
# 2  ЗП не указана      SQL, Power BI, Python, СУБД, BPMN, Clickhouse
# 3  ЗП не указана  MS Office, SQL, Python, Hadoop, Нive, Аналитич...
# 4  ЗП не указана                                                NaN
#
#   hard_skills_from_description soft_skills_from_description         vac_name  \
# 0                          NaN                          NaN  аналитик данных
# 1                          NaN                          NaN  аналитик данных
# 2                          NaN                          NaN  аналитик данных
# 3       Pandas, Юнит-экономика                 Коммуникация  аналитик данных
# 4                          NaN                 Документация  аналитик данных
#
#   month
# 0   5.0
# 1   5.0
# 2   5.0
# 3   5.0
# 4   5.0
#
# [5 rows x 22 columns]

# %%
employer_counts_da = data_da['employer'].value_counts().head(5) # подсчет количества вакансий по работодателям
employer_counts_da
# Out:
# employer
# СБЕР                      210
# Ozon                       31
# WILDBERRIES                27
# Т1                         22
# МАГНИТ, Розничная сеть     21
# Name: count, dtype: int64

# %%
# Фильтрация данных по топ-5 работодателям
top_employers_da = employer_counts_da.index
df_top_da = data_da[data_da['employer'].isin(top_employers_da)] 
df_top_da.head(5)
# Out:
#            id                                 name        published_at  \
# 7   100069131                        дата аналитик 2024-05-24 13:05:01
# 10  100077503                         data analyst 2024-05-24 14:14:00
# 18  100097062                         data analyst 2024-05-24 17:05:00
# 19  100101205  аналитик данных в клиентский сервис 2024-05-28 13:45:37
# 20  100103095           аналитик данных (антифрод) 2024-05-28 13:45:38
#
#                       alternate_url      type employer             department  \
# 7   https://hh.ru/vacancy/100069131  Открытая     СБЕР     Сбер для экспертов
# 10  https://hh.ru/vacancy/100077503  Открытая     СБЕР     Сбер для экспертов
# 18  https://hh.ru/vacancy/100097062  Открытая     СБЕР     Сбер для экспертов
# 19  https://hh.ru/vacancy/100101205  Открытая     Ozon  Ozon Офис и Коммерция
# 20  https://hh.ru/vacancy/100103095  Открытая     Ozon  Ozon Офис и Коммерция
#
#                area           experience  \
# 7   Санкт-Петербург  Junior+ (1-3 years)
# 10           Москва   Middle (3-6 years)
# 18           Москва  Junior+ (1-3 years)
# 19           Москва  Junior+ (1-3 years)
# 20           Москва  Junior+ (1-3 years)
#
#                                            key_skills  ...  \
# 7   ['Документация', 'Проактивность', 'Коммуникация']  ...
# 10                                         ['Pandas']  ...
# 18                     ['confluence', 'Документация']  ...
# 19  ['Python', 'Коммуникация', 'SQL', 'Торговая пл...  ...
# 20                   ['Python', 'SQL', 'Маркетплейс']  ...
#
#                                           description  \
# 7   команда данных по инвестиционным продуктам. мы...
# 10  в команду data science ищем руководителя напра...
# 18  мы, управление зарплатных проектов блока сеть ...
# 19  в отдел аналитики клиентского сервиса требуетс...
# 20  в отдел аналитики фрода и контроля качества тр...
#
#                                description_lemmatized salary_from salary_to  \
# 7   команда данные инвестиционный продукт развиват...         NaN       NaN
# 10  команда data science искать руководитель напра...         NaN       NaN
# 18  управление зарплатной проект блок сеть продажа...         NaN       NaN
# 19  отдел аналитик клиентский сервис требоваться а...         NaN       NaN
# 20  отдел аналитик фрод контроль качество требоват...         NaN       NaN
#
#        salary_bin  key_skills_from_key_skills_field  \
# 7   ЗП не указана                               NaN
# 10  ЗП не указана                               NaN
# 18  ЗП не указана                               NaN
# 19  ЗП не указана    SQL, Python, Торговая площадка
# 20  ЗП не указана          SQL, Python, Маркетплейс
#
#    hard_skills_from_description               soft_skills_from_description  \
# 7                           NaN  Коммуникация, Документация, Проактивность
# 10                       Pandas                                        NaN
# 18                   confluence                               Документация
# 19                          NaN                               Коммуникация
# 20                          NaN                                        NaN
#
#            vac_name month
# 7   аналитик данных   5.0
# 10  аналитик данных   5.0
# 18  аналитик данных   5.0
# 19  аналитик данных   5.0
# 20  аналитик данных   5.0
#
# [5 rows x 22 columns]

# %%
# Группировка данных по работодателям и месяцам
df_grouped_da = df_top_da.groupby(['month', 'employer']).size().unstack(fill_value=0)
df_grouped_da
# Out:
# employer  Ozon  WILDBERRIES  МАГНИТ, Розничная сеть  СБЕР  Т1
# month
# 3.0          5            3                       3    34   4
# 4.0          9           10                       9    60   7
# 5.0         14           13                       8   101   9

# %%
# Подсчет количества вакансий по работодателям
employer_counts_ds = data_ds['employer'].value_counts().head(5)
employer_counts_ds
# Out:
# employer
# СБЕР            164
# Ozon             24
# Samokat.tech     18
# Газпромбанк      15
# Т1               15
# Name: count, dtype: int64

# %%
# Фильтрация данных по топ-5 работодателям
top_employers_ds = employer_counts_ds.index
df_top_ds = data_ds[data_ds['employer'].isin(top_employers_ds)]
df_top_ds.head(5)
# Out:
#            id                                           name  \
# 0   100049339              стажер data science (новосибирск)
# 3   100076648                         team lead data science
# 7   100094269             middle/senior data scientist (llm)
# 13  100336712  data scientist, маркетплейс, контент и товары
# 24  100426833                          junior data scientist
#
#           published_at                    alternate_url      type employer  \
# 0  2024-05-24 09:37:04  https://hh.ru/vacancy/100049339  Открытая     СБЕР
# 3  2024-05-24 10:28:18  https://hh.ru/vacancy/100076648  Открытая     СБЕР
# 7  2024-05-24 13:05:01  https://hh.ru/vacancy/100094269  Открытая     СБЕР
# 13 2024-05-24 14:36:52  https://hh.ru/vacancy/100336712  Открытая     Ozon
# 24 2024-05-24 20:56:32  https://hh.ru/vacancy/100426833  Открытая     СБЕР
#
#                         department         area             experience  \
# 0               Сбер для экспертов  Новосибирск  Junior (no experince)
# 3               Сбер для экспертов       Москва     Middle (3-6 years)
# 7               Сбер для экспертов       Москва     Middle (3-6 years)
# 13  Ozon Информационные технологии       Москва    Junior+ (1-3 years)
# 24              Сбер. Data Science       Москва    Junior+ (1-3 years)
#
#                                          key_skills  ...  \
# 0                                                []  ...
# 3                                                []  ...
# 7                                                []  ...
# 13  ['Python', 'PyTorch', 'confluence', 'ИТ', 'IT']  ...
# 24    ['Python', 'Pandas', 'Юнит-экономика', 'SQL']  ...
#
#                                           description  \
# 0   sberseasons - оплачиваемая программа стажирово...
# 3   наша команда разрабатывает модели машинного об...
# 7   ищем senior\middle+ data scientist в команду s...
# 13  мы ищем талантливого data scientist для нашей ...
# 24  блок «управление благосостоянием» объединяет в...
#
#                                description_lemmatized salary_from salary_to  \
# 0   sberseasons оплачивать программа стажировка ра...         NaN       NaN
# 3   наш команда разрабатывать модель машинный обуч...         NaN       NaN
# 7   искать senior middle data scientist команда sb...         NaN       NaN
# 13  искать талантливый data scientist наш команда ...         NaN       NaN
# 24  блок управление благосостояние объединять упра...         NaN       NaN
#
#        salary_bin  key_skills_from_key_skills_field  \
# 0   ЗП не указана                               NaN
# 3   ЗП не указана                               NaN
# 7   ЗП не указана                               NaN
# 13  ЗП не указана           Python, PyTorch, ИТ, IT
# 24  ЗП не указана                       Python, SQL
#
#    hard_skills_from_description soft_skills_from_description        vac_name  \
# 0                           NaN                          NaN  data scientist
# 3                           NaN                          NaN  data scientist
# 7                           NaN                          NaN  data scientist
# 13                   confluence                          NaN  data scientist
# 24       Pandas, Юнит-экономика                          NaN  data scientist
#
#    month
# 0      5
# 3      5
# 7      5
# 13     5
# 24     5
#
# [5 rows x 22 columns]

# %%
# Группировка данных по работодателям и месяцам
df_grouped_ds = df_top_ds.groupby(['month', 'employer']).size().unstack(fill_value=0)
df_grouped_ds
# Out:
# employer  Ozon  Samokat.tech  Газпромбанк  СБЕР  Т1
# month
# 3            6             7            1    56   2
# 4           13            10           12    61   5
# 5            5             1            2    47   8

# %%
# Построение графиков
fig, axs = plt.subplots(1, 2, figsize=(15, 5))

df_grouped_da.plot(kind='line', marker='o', ax=axs[0])
axs[0].set_title('Изменение количества вакансий для Дата аналитиков по работодателям')
axs[0].set_xlabel('Месяц')
axs[0].set_ylabel('Количество вакансий')
axs[0].legend(title='Работодатель')
axs[0].grid(True)

df_grouped_ds.plot(kind='line', marker='o', ax=axs[1])
axs[1].set_title('Изменение количества вакансий для Дата сайнтистов по работодателям')
axs[1].set_xlabel('Месяц')
axs[1].set_ylabel('Количество вакансий')
axs[1].legend(title='Работодатель')
axs[1].grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# **Вывод по разделу 3.2.1**
#
# Мы проанлизировали помесячную динамику вакансий "Аналитик данных" и "Data Scientist" в разбивке по работодателям за период с марта по май 2024.
#
# Во первых на графике мы видим, что в не зависимости от специальности больше всего вакансий у Сбера.
# Количество вакансий "Аналитика данных" достигает пика в мае, при этом, если говорить про вакансии "Data Scientist", то мы видим рост в апреле и уменьшение количества в маю.
#
# Количество вакансий "Аналитика данных" компании Озон для вакансии Аналитика данных повторяет динамику Сбера. При этом вакансии компаний WILDBERRIES	и Банк ВТБ (ПАО) показывают рост с марта по май 2024 года.
#
# Если говорить про вакансии "Data Scientist", то в топ работодателей попали такие компании как Ozon, Samokat.tech, Газпромбанк и Т1. Вакансии копаний Ozon и Газпромбанк в целом повторяют динамику Сбера

# %% [markdown]
# #### 3.2.2 Топ работадателей по числу вакансий в разбивке по грейдам

# %%
# формируем сводную таблицу для вывода топ работадателей с фильтрацией по вакансии и грейду
data.query('vac_name=="аналитик данных" and experience=="Junior (no experince)"').pivot_table(index='employer', values='id', aggfunc='count').sort_values(by='id',ascending=False).head(5)
# Out:
#                               id
# employer
# СБЕР                          11
# МАГНИТ, Розничная сеть         5
# Согласие, страховая компания   4
# ANCOR                          2
# СИБУР, Группа компаний         2

# %%
# формируем сводную таблицу для вывода топ работадателей с фильтрацией по вакансии и грейду
data.query('vac_name=="аналитик данных" and experience=="Junior+ (1-3 years)"').pivot_table(index='employer', values='id', aggfunc='count').sort_values(by='id',ascending=False).head(5)
# Out:
#                                               id
# employer
# СБЕР                                         137
# МАГНИТ, Розничная сеть                        15
# Ozon                                          15
# Банк ВТБ (ПАО)                                15
# ГКУ Центр занятости населения города Москвы   11

# %%
# формируем сводную таблицу для вывода топ работадателей с фильтрацией по вакансии и грейду
data.query('vac_name=="аналитик данных" and experience=="Middle (3-6 years)"').pivot_table(index='employer', values='id', aggfunc='count').sort_values(by='id',ascending=False).head(5)
# Out:
#              id
# employer
# СБЕР         62
# Т1           18
# WILDBERRIES  16
# Ozon         14
# Яндекс       11

# %%
# формируем сводную таблицу для вывода топ работадателей с фильтрацией по вакансии и грейду
data.query('vac_name=="аналитик данных" and experience=="Senior (6+ years)"').pivot_table(index='employer', values='id', aggfunc='count').sort_values(by='id',ascending=False).head(5)
# Out:
#                     id
# employer
# Reinvent Baltics     2
# Леруа Мерлен         2
# Aramco Innovations   1
# B2Broker             1
# CloudPayments        1

# %%
# формируем сводную таблицу для вывода топ работадателей с фильтрацией по вакансии и греду
data.query('vac_name=="data scientist" and experience=="Junior (no experince)"').pivot_table(index='employer', values='id', aggfunc='count').sort_values(by='id',ascending=False).head(5)
# Out:
#                       id
# employer
# СБЕР                  11
# Молвер                 5
# Ozon                   3
# Правительство Москвы   3
# Lamoda Tech            2

# %%
# формируем сводную таблицу для вывода топ работадателей с фильтрацией по вакансии и греду
data.query('vac_name=="data scientist" and experience=="Junior+ (1-3 years)"').pivot_table(index='employer', values='id', aggfunc='count').sort_values(by='id',ascending=False).head(5)
# Out:
#                                id
# employer
# СБЕР                           78
# Ростелеком                     11
# Сахалин - Остров Возможностей   9
# 1221Системс                     7
# Т1                              7

# %%
# формируем сводную таблицу для вывода топ работадателей с фильтрацией по вакансии и греду
data.query('vac_name=="data scientist" and experience=="Middle (3-6 years)"').pivot_table(index='employer', values='id', aggfunc='count').sort_values(by='id',ascending=False).head(5)
# Out:
#               id
# employer
# СБЕР          73
# Ozon          15
# WILDBERRIES   12
# Samokat.tech  11
# Газпромбанк    9

# %%
# формируем сводную таблицу для вывода топ работадателей с фильтрацией по вакансии и греду
data.query('vac_name=="data scientist" and experience=="Senior (6+ years)"').pivot_table(index='employer', values='id', aggfunc='count').sort_values(by='id',ascending=False).head(5)
# Out:
#                     id
# employer
# Fundraise Up         2
# СБЕР                 2
# Sape                 2
# Aramco Innovations   2
# БиАйЭй-Технолоджиз   2

# %%
# Создание фигуры и осей
fig, axs = plt.subplots(4, 2, figsize=(15, 20))

# Список специальностей и грейдов
specialties = ['аналитик данных', 'data scientist']
grades = ['Junior (no experince)', 'Junior+ (1-3 years)', 'Middle (3-6 years)', 'Senior (6+ years)']

# Построение графиков
for i, grade in enumerate(grades):
    for j, specialty in enumerate(specialties):
        ax = axs[i, j]
        subset = data.query(f'vac_name=="{specialty}" and experience=="{grade}"').pivot_table(index='employer', values='id', aggfunc='count').sort_values(by='id', ascending=False).head(5)
        subset.plot(kind='pie', y='id', ax=ax, legend=False, autopct='%1.1f%%')
        ax.set_title(f'{specialty} ({grade})')
        ax.set_ylabel('')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Вывод по разделу 3.2.2**
#
# Мы проанализировали ТОП-5 работодателей в зависимости от грейда, указанной в вакансии.
# Для вакансии аналитика данных греда Junior (no experince) на первом месте стоит Сбер, у которого большего всего вакансий. Таже картина повторяется и для вакансии data scientist. Также компании Сбер первая по числу вакансий и для грейдов Junior+ (1-3 years), и Middle (3-6 years) обоих специальностей.
# Для грейда Senior (6+ years) вакансий аналитика данных на первом месте по числу вакансий стоит компания Леруа Мерлен, а для data scientist компания Fundraise Up

# %% [markdown]
# #### 3.2.3 Определение типичного места работы для вакансий "Аналитик данных" и "Data Scientist" в части предлагаемой зарплаты

# %%
# заменяем пустые значения в столбце с зарплатой средним значением по региону
for t in data['area'].unique():
    data.loc[(data['area'] == t) & (data['salary_from'].isna()), 'salary_from'] = \
    data.loc[(data['area'] == t), 'salary_from'].mean()
    data.loc[(data['area'] == t) & (data['salary_to'].isna()), 'salary_to'] = \
    data.loc[(data['area'] == t), 'salary_to'].mean()

# %%
data[data['salary_to']. isnull ()] # проверяем  пустые значения в столбце с зарплатой
# Out:
#              id                                               name  \
# 42    100377258             аналитик данных (менеджер по развитию)
# 176    91481640                                    аналитик данных
# 214    92444490  аналитик данных bi отдела автоматизации (г. во...
# 225    92761981                     аналитик данных / data analyst
# 227    92831135  аналитик данных о реализации нефтепродуктов, т...
# 272    93447350               стажер специалиста (аналитик данных)
# 306    93837132                                    аналитик данных
# 329    94094674                                    аналитик данных
# 342    94248757             менеджер по развитию (аналитик данных)
# 403    94719070                           аналитик данных bi / щлз
# 417    94768610                                    аналитик данных
# 431    94827455                                       data analyst
# 434    94839129                                аналитик данных ivr
# 461    94973440                                аналитик данных ivr
# 473    95053495                                аналитик данных ivr
# 491    95108699                 аналитик данных (офис г. владимир)
# 493    95111095                   clickhouse dba / аналитик данных
# 505    95177062          аналитик данных внутритрубной диагностики
# 519    95213012                                аналитик данных ivr
# 528    95262750           аналитик данных (специалист 1 категории)
# 603    95699215                             аналитик данных x-code
# 612    95725386                                    аналитик данных
# 622    95794749                                    аналитик данных
# 626    95801370                                аналитик данных ivr
# 809    96629245                 аналитик данных контактных центров
# 811    96633076                                аналитик данных ivr
# 827    96728809                                    аналитик данных
# 840    96822876                                    аналитик данных
# 848    96878374                                       data analyst
# 858    96998030                                    аналитик данных
# 859    96998110                                    аналитик данных
# 950    97309080                           аналитик данных (1с:зуп)
# 975    97431897      младший аналитик данных (junior data analyst)
# 985    97453234                           аналитик данных (стажер)
# 1038   97758629                           аналитик данных bi / щлз
# 1073   97921288                                    аналитик данных
# 1074   97921289                                    аналитик данных
# 1157   98359534                      аналитик данных отдела продаж
# 1172   98474482           аналитик данных в r&d / data analyst r&d
# 1281   99037697                                аналитик данных ivr
# 1294   99125009                           аналитик данных (1с:зуп)
# 1310   99273834                                    аналитик данных
# 1361   99703309              финансист/аналитик данных (экономист)
# 1396   99953158                                    аналитик данных
# 1407   99988999  аналитик данных на производстве \ data analyst...
# 1408   99989203  аналитик данных на производстве \ data analyst...
# 1728   95222336  бизнес-аналитик со знанием sql (удаленно)/data...
# 1778   95588128                  data scientist, г. южно-сахалинск
# 1834   95916293                                     data scientist
#
#             published_at                    alternate_url      type  \
# 42   2024-05-27 15:17:29  https://hh.ru/vacancy/100377258  Открытая
# 176  2024-03-21 19:18:31   https://hh.ru/vacancy/91481640  Открытая
# 214  2024-04-18 08:11:35   https://hh.ru/vacancy/92444490  Открытая
# 225  2024-04-06 13:13:16   https://hh.ru/vacancy/92761981  Открытая
# 227  2024-04-27 12:50:59   https://hh.ru/vacancy/92831135  Открытая
# 272  2024-03-06 06:06:41   https://hh.ru/vacancy/93447350  Открытая
# 306  2024-03-28 08:02:35   https://hh.ru/vacancy/93837132  Открытая
# 329  2024-03-07 12:15:06   https://hh.ru/vacancy/94094674  Открытая
# 342  2024-04-22 11:56:58   https://hh.ru/vacancy/94248757  Открытая
# 403  2024-03-13 20:43:33   https://hh.ru/vacancy/94719070  Открытая
# 417  2024-03-14 14:55:38   https://hh.ru/vacancy/94768610  Открытая
# 431  2024-04-21 15:19:04   https://hh.ru/vacancy/94827455  Открытая
# 434  2024-03-15 15:45:03   https://hh.ru/vacancy/94839129  Открытая
# 461  2024-03-18 15:15:05   https://hh.ru/vacancy/94973440  Открытая
# 473  2024-03-19 13:06:03   https://hh.ru/vacancy/95053495  Открытая
# 491  2024-03-20 10:23:56   https://hh.ru/vacancy/95108699  Открытая
# 493  2024-03-20 10:49:14   https://hh.ru/vacancy/95111095  Открытая
# 505  2024-03-21 10:21:26   https://hh.ru/vacancy/95177062  Открытая
# 519  2024-03-21 15:16:05   https://hh.ru/vacancy/95213012  Открытая
# 528  2024-03-22 10:12:46   https://hh.ru/vacancy/95262750  Открытая
# 603  2024-03-28 13:37:01   https://hh.ru/vacancy/95699215  Открытая
# 612  2024-03-28 17:27:03   https://hh.ru/vacancy/95725386  Открытая
# 622  2024-03-29 13:51:45   https://hh.ru/vacancy/95794749  Открытая
# 626  2024-03-29 15:05:06   https://hh.ru/vacancy/95801370  Открытая
# 809  2024-05-14 09:54:49   https://hh.ru/vacancy/96629245  Открытая
# 811  2024-04-10 15:48:04   https://hh.ru/vacancy/96633076  Открытая
# 827  2024-05-13 06:49:59   https://hh.ru/vacancy/96728809  Открытая
# 840  2024-04-12 15:04:46   https://hh.ru/vacancy/96822876  Открытая
# 848  2024-04-13 13:27:12   https://hh.ru/vacancy/96878374  Открытая
# 858  2024-04-15 11:46:29   https://hh.ru/vacancy/96998030  Открытая
# 859  2024-04-15 11:47:10   https://hh.ru/vacancy/96998110  Открытая
# 950  2024-05-20 05:50:26   https://hh.ru/vacancy/97309080  Открытая
# 975  2024-05-05 16:47:09   https://hh.ru/vacancy/97431897  Открытая
# 985  2024-05-12 18:13:37   https://hh.ru/vacancy/97453234  Открытая
# 1038 2024-04-23 21:41:03   https://hh.ru/vacancy/97758629  Открытая
# 1073 2024-05-13 15:39:06   https://hh.ru/vacancy/97921288  Открытая
# 1074 2024-05-13 15:39:06   https://hh.ru/vacancy/97921289  Открытая
# 1157 2024-05-03 17:09:50   https://hh.ru/vacancy/98359534  Открытая
# 1172 2024-05-06 14:38:32   https://hh.ru/vacancy/98474482  Открытая
# 1281 2024-05-15 13:03:03   https://hh.ru/vacancy/99037697  Открытая
# 1294 2024-05-16 16:21:57   https://hh.ru/vacancy/99125009  Открытая
# 1310 2024-05-17 13:16:30   https://hh.ru/vacancy/99273834  Открытая
# 1361 2024-05-21 13:22:45   https://hh.ru/vacancy/99703309  Открытая
# 1396 2024-05-23 13:33:21   https://hh.ru/vacancy/99953158  Открытая
# 1407 2024-05-23 19:35:56   https://hh.ru/vacancy/99988999  Открытая
# 1408 2024-05-23 19:40:04   https://hh.ru/vacancy/99989203  Открытая
# 1728 2024-03-06 17:22:56   https://hh.ru/vacancy/95222336  Открытая
# 1778 2024-04-03 14:56:12   https://hh.ru/vacancy/95588128  Открытая
# 1834 2024-04-22 11:56:58   https://hh.ru/vacancy/95916293  Открытая
#
#                                        employer          department  \
# 42                                Деловые Линии                 NaN
# 176                                  ТехноГрупп                 NaN
# 214                     Группа компаний АГРОЭКО                 NaN
# 225                                        Марс                 NaN
# 227                                 ИК СИБИНТЕК       ИК "Сибинтек"
# 272                      СИБУР, Группа компаний               Сибур
# 306                                     РАТИМИР                 NaN
# 329                                     МедСофт                 NaN
# 342                               Деловые Линии                 NaN
# 403                                      ДОМ.РФ           ДОМ.РФ ИТ
# 417                            Организация Агат                 NaN
# 431                                  StudyWorld                 NaN
# 434                                        СБЕР  Сбер для экспертов
# 461                                        СБЕР  Сбер для экспертов
# 473                                        СБЕР  Сбер для экспертов
# 491                                         Abi                 NaN
# 493                     Смарт Геймс Девелопмент                 NaN
# 505                                        НЦТО                 NaN
# 519                                        СБЕР  Сбер для экспертов
# 528                                    Ай-Пласт                 NaN
# 603                                        СБЕР  Сбер для экспертов
# 612              Восточная горнорудная компания                 NaN
# 622                              Россельхозбанк                 NaN
# 626                                        СБЕР  Сбер для экспертов
# 809                                         МТС              «МТС»
# 811                                        СБЕР  Сбер для экспертов
# 827                                     Гринфин                 NaN
# 840                                    Blissweb                 NaN
# 848                                        KODE                 NaN
# 858                                 ТЕЛЕКОНТАКТ                 NaN
# 859                                 ТЕЛЕКОНТАКТ                 NaN
# 950              РУСАЛ, Центр подбора персонала                 NaN
# 975                           Компания CADesign                 NaN
# 985                           Компания CADesign                 NaN
# 1038                                     ДОМ.РФ           ДОМ.РФ ИТ
# 1073  Транспортная Компания Технология Движения                 NaN
# 1074  Транспортная Компания Технология Движения                 NaN
# 1157                                     Артель                 NaN
# 1172                                       Марс                 NaN
# 1281                                       СБЕР  Сбер для экспертов
# 1294             РУСАЛ, Центр подбора персонала                 NaN
# 1310             РУСАЛ, Центр подбора персонала                 NaN
# 1361                         Центр Безопасности                 NaN
# 1396                           Организация Агат                 NaN
# 1407                                       Марс                 NaN
# 1408                                       Марс                 NaN
# 1728                                        ПКБ                 NaN
# 1778                                       СБЕР  Сбер. Data Science
# 1834                               Adwirk Group                 NaN
#
#                               area             experience  \
# 42                            Омск    Junior+ (1-3 years)
# 176                    Дзержинский    Junior+ (1-3 years)
# 214                       Белгород    Junior+ (1-3 years)
# 225                        Ступино    Junior+ (1-3 years)
# 227                         Рязань  Junior (no experince)
# 272      Северск (Томская область)  Junior (no experince)
# 306                          Артем    Junior+ (1-3 years)
# 329                         Липецк     Middle (3-6 years)
# 342                           Омск    Junior+ (1-3 years)
# 403                       Щербинка    Junior+ (1-3 years)
# 417                        Королев    Junior+ (1-3 years)
# 431      Киров (Кировская область)    Junior+ (1-3 years)
# 434                     Вейделевка    Junior+ (1-3 years)
# 461                  Горно-Алтайск    Junior+ (1-3 years)
# 473                  Горно-Алтайск    Junior+ (1-3 years)
# 491   Иваново (Ивановская область)    Junior+ (1-3 years)
# 493   Иваново (Ивановская область)    Junior+ (1-3 years)
# 505                       Луховицы  Junior (no experince)
# 519                       Златоуст    Junior+ (1-3 years)
# 528               Набережные Челны     Middle (3-6 years)
# 603                         Байбек  Junior (no experince)
# 612                        Иркутск    Junior+ (1-3 years)
# 622   Иваново (Ивановская область)    Junior+ (1-3 years)
# 626                        Турочак    Junior+ (1-3 years)
# 809                         Рязань  Junior (no experince)
# 811                      Алтайское    Junior+ (1-3 years)
# 827                     Красноярск    Junior+ (1-3 years)
# 840                        Саратов  Junior (no experince)
# 848                    Калининград    Junior+ (1-3 years)
# 858                        Саратов     Middle (3-6 years)
# 859                       Оренбург     Middle (3-6 years)
# 950                     Красноярск    Junior+ (1-3 years)
# 975   Иваново (Ивановская область)  Junior (no experince)
# 985   Иваново (Ивановская область)  Junior (no experince)
# 1038                      Щербинка    Junior+ (1-3 years)
# 1073  Пушкино (Московская область)    Junior+ (1-3 years)
# 1074                        Мытищи    Junior+ (1-3 years)
# 1157                          Тула    Junior+ (1-3 years)
# 1172                       Ступино    Junior+ (1-3 years)
# 1281                      Златоуст    Junior+ (1-3 years)
# 1294                     Волгоград    Junior+ (1-3 years)
# 1310                       Дмитров    Junior+ (1-3 years)
# 1361                        Якутск    Junior+ (1-3 years)
# 1396                       Королев    Junior+ (1-3 years)
# 1407                       Ступино    Junior+ (1-3 years)
# 1408                      Одинцово    Junior+ (1-3 years)
# 1728                        Липецк    Junior+ (1-3 years)
# 1778                Южно-Сахалинск    Junior+ (1-3 years)
# 1834                   Калининград    Junior+ (1-3 years)
#
#                                              key_skills  ...  \
# 42    ['Анализ данных', 'SQL', 'Power BI', 'Статисти...  ...
# 176                          ['Аналитическое мышление']  ...
# 214                                    ['Документация']  ...
# 225                                                  []  ...
# 227   ['Анализ данных', 'SQL', 'MS Access', 'Python'...  ...
# 272                                        ['MS Excel']  ...
# 306                                                  []  ...
# 329                          ['Аналитическое мышление']  ...
# 342   ['MS SQL', 'Бизнес-анализ', 'Power BI', 'Dax',...  ...
# 403                                                  []  ...
# 417   ['Коммуникация', 'Сбор и анализ информации', '...  ...
# 431   ['SQL', 'Python', 'Pandas', 'Математическая ст...  ...
# 434                                                  []  ...
# 461                                                  []  ...
# 473                                                  []  ...
# 491                                                  []  ...
# 493                                          ['Pandas']  ...
# 505   ['Английский язык', 'Грамотная речь', 'Работа ...  ...
# 519                                                  []  ...
# 528   ['Способность к саморазвитию', 'Инициативность...  ...
# 603                                                  []  ...
# 612                                          ['Pandas']  ...
# 622   ['MS SQL', 'Деловая переписка', 'Экономический...  ...
# 626                                                  []  ...
# 809       ['Аналитическое мышление', 'SQL', 'MS Excel']  ...
# 811                                                  []  ...
# 827                                                  []  ...
# 840   ['SQL', 'Python', 'Исследовательский анализ да...  ...
# 848                          ['Коммуникация', 'Pandas']  ...
# 858   ['Анализ данных', 'MS PowerPoint', 'SQL', 'Pow...  ...
# 859   ['Анализ данных', 'MS PowerPoint', 'SQL', 'Pow...  ...
# 950                          ['Аналитическое мышление']  ...
# 975                                                  []  ...
# 985   ['сводные таблицы', 'формулы', 'Ехсеl', 'Micro...  ...
# 1038                                                 []  ...
# 1073  ['Анализ данных', 'Аналитические способности',...  ...
# 1074  ['Анализ данных', 'Аналитические способности',...  ...
# 1157  ['Анализ данных', 'E-Commerce', 'Сводные табли...  ...
# 1172                                                 []  ...
# 1281                                                 []  ...
# 1294                         ['Аналитическое мышление']  ...
# 1310                ['Анализ данных', 'Tableau', 'SQL']  ...
# 1361  ['Финансовый контроль', 'Финансовый анализ', '...  ...
# 1396  ['Коммуникация', 'Сбор и анализ информации', '...  ...
# 1407  ['Анализ данных', 'SQL', 'MS Power BI', 'Pytho...  ...
# 1408  ['Анализ данных', 'SQL', 'MS Power BI', 'Pytho...  ...
# 1728  ['Планирование карьеры', 'Умение планировать',...  ...
# 1778  ['Python', 'Machine Learning', 'SQL', 'Data Sc...  ...
# 1834  ['Python', 'Работа с базами данных', 'Математи...  ...
#
#                                             description  \
# 42    группа компаний &quot;деловые линии&quot;‚ оди...
# 176   компания техногрупп является лидирующим россий...
# 214   вакансия открыта в связи с расширением отдела ...
# 225   мы ищем аналитика данных, который с помощью да...
# 227   обязанности:  сбор и подготовка исходных данны...
# 272   ооо «томскнефтехим», сибур холдинг приглашает ...
# 306   в обязанности будет входить:• анализ данных и ...
# 329   о компании:аккредитованная it-компания медсофт...
# 342   группа компаний &quot;деловые линии&quot;‚ оди...
# 403   ао «щлз» – флагман российского лифтостроения, ...
# 417   обязанности:  подготовка отчетов с аналитическ...
# 431   всем привет!меня зовут галя, я занимаюсь росто...
# 434   ищем аналитика данных в канал виртуальный асси...
# 461   ищем аналитика данных в канал виртуальный асси...
# 473   ищем аналитика данных в канал виртуальный асси...
# 491   обязанности:  формирование чек листов и контро...
# 493   смарт геймс девелопмент - разработчик игр для ...
# 505   обязанности: - компьютерная обработка и анализ...
# 519   ищем аналитика данных в канал виртуальный асси...
# 528   ай-пласт — лидирующее российское предприятие п...
# 603   ищем аналитика данных в канал виртуальный асси...
# 612   мы активно развиваемся и расширяем нашу команд...
# 622   обязанности:  развитие аналитической отчетност...
# 626   ищем аналитика данных в канал виртуальный асси...
# 809   мтс — это мультисервисная цифровая экосистема....
# 811   ищем аналитика данных в канал виртуальный асси...
# 827   обязанности:   ведение свода ит заявок бину, п...
# 840   ‼мы ищem нobых сотрудниkоb в нашу komaнду‼ ктo...
# 848   привет! для усиления команды ищем аналитика бд...
# 858   телеконтакт – один из крупнейших аутсорсинговы...
# 859   телеконтакт – один из крупнейших аутсорсинговы...
# 950   ок русал приглашает на работу аналитика данных...
# 975   cadesign создает и продвигает в digital проект...
# 985   cadesign создает и продвигает в digital проект...
# 1038  ао «щлз» – флагман российского лифтостроения, ...
# 1073  транспортная компания «тк технология движения»...
# 1074  транспортная компания «тк технология движения»...
# 1157  производителю детской верхней одежды и головны...
# 1172  мы ищем аналитика данных, который с помощью да...
# 1281  ищем аналитика данных в канал виртуальный асси...
# 1294  ок русал приглашает на работу аналитика hr-дан...
# 1310  обязанности:  выполнение проектов в области вы...
# 1361  обязанности:  консультации по ведению финансов...
# 1396  обязанности:  подготовка отчетов с аналитическ...
# 1407  аналитик будет заниматься сбором, обработкой, ...
# 1408  аналитик будет заниматься сбором, обработкой, ...
# 1728  пкб — технологичная клиентоориентированная ком...
# 1778  центр искусственного интеллекта сахалина ищет ...
# 1834  atlantes.io активно расширяется и в поиске тал...
#
#                                  description_lemmatized salary_from salary_to  \
# 42    группа компания quot деловой линия quot лидер ...    120000.0       NaN
# 176   компания техногруппа являться лидировать росси...         NaN       NaN
# 214   вакансия открывать связь расширение отдел авто...         NaN       NaN
# 225   искать аналитик данные помощь данные помогать ...         NaN       NaN
# 227   обязанность сбор подготовка исходный данные ра...     61000.0       NaN
# 272   томскнефтехим сибур холдинг приглашать стажиро...         NaN       NaN
# 306   обязанность входить анализ данные интерпретаци...         NaN       NaN
# 329   компания аккредитовать it компания медсофт зан...    100000.0       NaN
# 342   группа компания quot деловой линия quot лидер ...    120000.0       NaN
# 403   ао щлз флагман российский лифтостроение работа...         NaN       NaN
# 417   обязанность подготовка отчет аналитический вык...         NaN       NaN
# 431   привет звать галя заниматься рост studyworld e...         NaN       NaN
# 434   искать аналитика данные канал виртуальный асси...         NaN       NaN
# 461   искать аналитика данные канал виртуальный асси...         NaN       NaN
# 473   искать аналитика данные канал виртуальный асси...         NaN       NaN
# 491   обязанность формирование чек лист контрольный ...         NaN       NaN
# 493   смарт геймс девелопмент разработчик игра мобил...         NaN       NaN
# 505   обязанность компьютерный обработка анализ данн...     60000.0       NaN
# 519   искать аналитика данные канал виртуальный асси...         NaN       NaN
# 528   ай пласт лидировать российский предприятие про...    137000.0       NaN
# 603   искать аналитика данные канал виртуальный асси...         NaN       NaN
# 612   активно развиваться расширять наш команда связ...         NaN       NaN
# 622   обязанность развитие аналитический отчетность ...         NaN       NaN
# 626   искать аналитика данные канал виртуальный асси...         NaN       NaN
# 809   мтс мультисервисный цифровой экосистема создав...     61000.0       NaN
# 811   искать аналитика данные канал виртуальный асси...         NaN       NaN
# 827   обязанность ведение свод ита заявка бина подде...         NaN       NaN
# 840   ищem нobых сотрудниkоb наш komaнду требоваться...     90000.0       NaN
# 848   привет усиление команда искать аналитик бд хот...         NaN       NaN
# 858   телеконтакте крупный аутсорсинговый колл центр...    180000.0       NaN
# 859   телеконтакте крупный аутсорсинговый колл центр...    180000.0       NaN
# 950   ока русала приглашать работа аналитик данные 1...         NaN       NaN
# 975   cadesign создавать продвигать digital проект ф...         NaN       NaN
# 985   cadesign создавать продвигать digital проект ф...         NaN       NaN
# 1038  ао щлз флагман российский лифтостроение работа...         NaN       NaN
# 1073  транспортный компания тк технология движение а...    100000.0       NaN
# 1074  транспортный компания тк технология движение а...    100000.0       NaN
# 1157  производитель детский верхний одежда головной ...     70000.0       NaN
# 1172  искать аналитик данные помощь данные помогать ...         NaN       NaN
# 1281  искать аналитика данные канал виртуальный асси...         NaN       NaN
# 1294  ока русала приглашать работа аналитик hr данны...         NaN       NaN
# 1310  обязанность выполнение проект область выявлени...         NaN       NaN
# 1361  обязанность консультация ведение финансовый уч...     60000.0       NaN
# 1396  обязанность подготовка отчет аналитический вык...         NaN       NaN
# 1407  аналитик заниматься сбор обработка изучение ан...         NaN       NaN
# 1408  аналитик заниматься сбор обработка изучение ан...         NaN       NaN
# 1728  пкб технологичный клиентоориентированный компа...    100000.0       NaN
# 1778  центр искусственный интеллект сахалин искать m...         NaN       NaN
# 1834  atlantes io активно расширяться поиск талантли...         NaN       NaN
#
#          salary_bin                   key_skills_from_key_skills_field  \
# 42    ЗП не указана  SQL, Анализ данных, Математическая статистика,...
# 176   ЗП не указана                                                NaN
# 214   ЗП не указана                                                NaN
# 225   ЗП не указана                                                NaN
# 227   ЗП не указана  SQL, Python, MS Access, Аналитическое мышление...
# 272   ЗП не указана                                           MS Excel
# 306   ЗП не указана                                                NaN
# 329   ЗП не указана                                                NaN
# 342   ЗП не указана  MS SQL, Бизнес-анализ, PostgreSQL, Базы данных...
# 403   ЗП не указана                                                NaN
# 417   ЗП не указана  Математический анализ, Аналитические исследова...
# 431   ЗП не указана  Математический анализ, Математическая статисти...
# 434   ЗП не указана                                                NaN
# 461   ЗП не указана                                                NaN
# 473   ЗП не указана                                                NaN
# 491   ЗП не указана                                                NaN
# 493   ЗП не указана                                                NaN
# 505   ЗП не указана  Пользователь ПК, Работа в команде, Грамотная р...
# 519   ЗП не указана                                                NaN
# 528   ЗП не указана  Коммуникативная гибкость, Системность мышления...
# 603   ЗП не указана                                                NaN
# 612   ЗП не указана                                                NaN
# 622   ЗП не указана  Аналитическое мышление, MS SQL, Базы данных, А...
# 626   ЗП не указана                                                NaN
# 809   ЗП не указана              SQL, MS Excel, Аналитическое мышление
# 811   ЗП не указана                                                NaN
# 827   ЗП не указана                                                NaN
# 840   ЗП не указана  Основы баз данных, SQL, Python, Исследовательс...
# 848   ЗП не указана                                                NaN
# 858   ЗП не указана  SQL, Power BI, Анализ данных, MS PowerPoint, Р...
# 859   ЗП не указана  SQL, Power BI, Анализ данных, MS PowerPoint, Р...
# 950   ЗП не указана                                                NaN
# 975   ЗП не указана                                                NaN
# 985   ЗП не указана  Ехсеl, Microsoft Power BI, сводные таблицы, фо...
# 1038  ЗП не указана                                                NaN
# 1073  ЗП не указана  Работа с базами данных, Деловая коммуникация, ...
# 1074  ЗП не указана  Работа с базами данных, Деловая коммуникация, ...
# 1157  ЗП не указана  Анализ данных, Аналитика, E-Commerce, Сводные ...
# 1172  ЗП не указана                                                NaN
# 1281  ЗП не указана                                                NaN
# 1294  ЗП не указана                                                NaN
# 1310  ЗП не указана                        SQL, Tableau, Анализ данных
# 1361  ЗП не указана  Финансовый анализ, Финансовое планирование, Фи...
# 1396  ЗП не указана  Математический анализ, Аналитические исследова...
# 1407  ЗП не указана  MS Power BI, Аналитика, Python, SQL, Tableau, ...
# 1408  ЗП не указана  MS Power BI, Аналитика, Python, SQL, Tableau, ...
# 1728  ЗП не указана  Работа в команде, SQL, Умение работать в колле...
# 1778  ЗП не указана  Python, Data Science, SQL, Machine Learning, М...
# 1834  ЗП не указана  Python, SQL, Работа с базами данных, Математич...
#
#      hard_skills_from_description soft_skills_from_description  \
# 42                            NaN                          NaN
# 176                           NaN       Аналитическое мышление
# 214                           NaN                 Документация
# 225                           NaN                          NaN
# 227                           NaN                 Документация
# 272                           NaN                          NaN
# 306                           NaN                          NaN
# 329                           NaN       Аналитическое мышление
# 342                           NaN                          NaN
# 403                           NaN                          NaN
# 417                           NaN                 Коммуникация
# 431                        Pandas                          NaN
# 434                           NaN                          NaN
# 461                           NaN                          NaN
# 473                           NaN                          NaN
# 491                           NaN                          NaN
# 493                        Pandas                          NaN
# 505                           NaN                 Документация
# 519                           NaN                          NaN
# 528                           NaN                          NaN
# 603                           NaN                          NaN
# 612                        Pandas                          NaN
# 622                           NaN                          NaN
# 626                           NaN                          NaN
# 809                           NaN                          NaN
# 811                           NaN                          NaN
# 827                           NaN                          NaN
# 840                           NaN                          NaN
# 848                        Pandas                 Коммуникация
# 858                           NaN                          NaN
# 859                           NaN                          NaN
# 950                           NaN       Аналитическое мышление
# 975                           NaN                          NaN
# 985                           NaN                          NaN
# 1038                          NaN                          NaN
# 1073                          NaN       Аналитическое мышление
# 1074                          NaN       Аналитическое мышление
# 1157                          NaN       Аналитическое мышление
# 1172                          NaN                          NaN
# 1281                          NaN                          NaN
# 1294                          NaN       Аналитическое мышление
# 1310                          NaN                          NaN
# 1361                          NaN       Аналитическое мышление
# 1396                          NaN                 Коммуникация
# 1407                          NaN                          NaN
# 1408                          NaN                          NaN
# 1728                          NaN                          NaN
# 1778                          NaN                 Коммуникация
# 1834                       Pandas                          NaN
#
#              vac_name month
# 42    аналитик данных     5
# 176   аналитик данных     4
# 214   аналитик данных     4
# 225   аналитик данных     3
# 227   аналитик данных     3
# 272   аналитик данных     3
# 306   аналитик данных     3
# 329   аналитик данных     3
# 342   аналитик данных     4
# 403   аналитик данных     3
# 417   аналитик данных     4
# 431   аналитик данных     4
# 434   аналитик данных     4
# 461   аналитик данных     5
# 473   аналитик данных     5
# 491   аналитик данных     4
# 493   аналитик данных     4
# 505   аналитик данных     4
# 519   аналитик данных     4
# 528   аналитик данных     4
# 603   аналитик данных     4
# 612   аналитик данных     5
# 622   аналитик данных     4
# 626   аналитик данных     4
# 809   аналитик данных     5
# 811   аналитик данных     5
# 827   аналитик данных     4
# 840   аналитик данных     4
# 848   аналитик данных     5
# 858   аналитик данных     4
# 859   аналитик данных     5
# 950   аналитик данных     5
# 975   аналитик данных     5
# 985   аналитик данных     5
# 1038  аналитик данных     5
# 1073  аналитик данных     5
# 1074  аналитик данных     5
# 1157  аналитик данных     5
# 1172  аналитик данных     4
# 1281  аналитик данных     5
# 1294  аналитик данных     3
# 1310  аналитик данных     3
# 1361  аналитик данных     5
# 1396  аналитик данных     3
# 1407  аналитик данных     3
# 1408  аналитик данных     3
# 1728   data scientist     3
# 1778   data scientist     4
# 1834   data scientist     4
#
# [49 rows x 22 columns]

# %%
data['salary_from'].fillna(0) # заполняем пустые значения нулями
# Out:
# 0        60000.000000
# 1       136829.397516
# 2        90000.000000
# 3       136829.397516
# 4       136829.397516
#             ...
# 2157     60000.000000
# 2158     60000.000000
# 2159     60000.000000
# 2160    136829.397516
# 2161    136829.397516
# Name: salary_from, Length: 2162, dtype: float64

# %%
data['salary_to'].fillna(0) # заполняем пустые значения нулями
# Out:
# 0       119713.333333
# 1       214055.069231
# 2       119713.333333
# 3       214055.069231
# 4       214055.069231
#             ...
# 2157    120833.333333
# 2158    184995.000000
# 2159    203333.333333
# 2160    214055.069231
# 2161    214055.069231
# Name: salary_to, Length: 2162, dtype: float64

# %%
data['salary_mean'] = data[['salary_from','salary_to']].mean(axis=1) # считаем среднее значение между данными с зарплатой с и по 
data.head()
# Out:
#           id                                    name        published_at  \
# 0  100039284  junior аналитик данных (исследователь) 2024-05-24 09:37:04
# 1  100039480                         аналитик данных 2024-05-24 09:39:00
# 2  100042705         аналитик данных (исследователь) 2024-05-24 10:01:25
# 3  100046788                 ведущий аналитик данных 2024-05-24 10:28:18
# 4  100056244                         аналитик данных 2024-05-24 11:27:40
#
#                      alternate_url      type           employer  \
# 0  https://hh.ru/vacancy/100039284  Открытая  DNS Головной офис
# 1  https://hh.ru/vacancy/100039480  Открытая              Комус
# 2  https://hh.ru/vacancy/100042705  Открытая  DNS Головной офис
# 3  https://hh.ru/vacancy/100046788  Открытая           Х5 Group
# 4  https://hh.ru/vacancy/100056244  Открытая             ЛУКОЙЛ
#
#                    department         area             experience  \
# 0                         NaN  Владивосток  Junior (no experince)
# 1                         NaN       Москва  Junior (no experince)
# 2                         NaN  Владивосток    Junior+ (1-3 years)
# 3  X5 GROUP, Центральный офис       Москва    Junior+ (1-3 years)
# 4                         NaN       Москва     Middle (3-6 years)
#
#                                           key_skills  ...  \
# 0              ['Power BI', 'СУБД', 'Python', 'SQL']  ...
# 1   ['MS SQL', 'Работа с базами данных', 'MS Excel']  ...
# 2  ['SQL', 'Power BI', 'СУБД', 'Python', 'Clickho...  ...
# 3  ['Анализ данных', 'Коммуникация', 'SQL', 'MS O...  ...
# 4                                   ['Документация']  ...
#
#                               description_lemmatized    salary_from  \
# 0  наш направление заниматься повышение эффективн...   60000.000000
# 1  сегодня комус крупный поставщик офисный товар ...  136829.397516
# 2  наш направление заниматься повышение эффективн...   90000.000000
# 3  задача разработка бизнес модель групповой прог...  136829.397516
# 4  обязанность участие проектирование разработка ...  136829.397516
#
#        salary_to     salary_bin  \
# 0  119713.333333  ЗП не указана
# 1  214055.069231  ЗП не указана
# 2  119713.333333  ЗП не указана
# 3  214055.069231  ЗП не указана
# 4  214055.069231  ЗП не указана
#
#                     key_skills_from_key_skills_field  \
# 0                        SQL, Power BI, Python, СУБД
# 1           Работа с базами данных, MS SQL, MS Excel
# 2      SQL, Power BI, Python, СУБД, BPMN, Clickhouse
# 3  MS Office, SQL, Python, Hadoop, Нive, Аналитич...
# 4                                                NaN
#
#    hard_skills_from_description soft_skills_from_description         vac_name  \
# 0                           NaN                          NaN  аналитик данных
# 1                           NaN                          NaN  аналитик данных
# 2                           NaN                          NaN  аналитик данных
# 3        Pandas, Юнит-экономика                 Коммуникация  аналитик данных
# 4                           NaN                 Документация  аналитик данных
#
#   month    salary_mean
# 0     5   89856.666667
# 1     5  175442.233373
# 2     5  104856.666667
# 3     5  175442.233373
# 4     5  175442.233373
#
# [5 rows x 23 columns]

# %%
data['salary_mean'].loc[data['vac_name'] == 'data scientist'].min()
# Out:
# 53131.25

# %%
data['salary_mean'].loc[data['vac_name'] == 'data scientist'].max()
# Out:
# 390000.0

# %%
data['salary_mean'].loc[data['vac_name'] == 'аналитик данных'].min()
# Out:
# 26000.0

# %%
data['salary_mean'].loc[data['vac_name'] == 'аналитик данных'].max()
# Out:
# 447750.0

# %%
salary_mean = data.pivot_table(index='experience', columns='vac_name', values='salary_mean',aggfunc='mean').reset_index() # формируем сводную таблицу со средней зарплатой в разбивке по вкансиям и грейдам 
salary_mean
# Out:
# vac_name             experience  data scientist  аналитик данных
# 0         Junior (no experince)   155967.637839    127543.540078
# 1           Junior+ (1-3 years)   165216.323361    155492.672877
# 2            Middle (3-6 years)   175620.679376    174088.901933
# 3             Senior (6+ years)   179558.998214    177853.786699

# %%
# Создание графика
fig, ax = plt.subplots()
salary_mean.plot(kind='line', x='experience', ax=ax)

# Добавление подписей и заголовков
ax.set_xlabel('Опыт')
ax.set_ylabel('Средняя зарплата')
ax.set_title('Средняя зарплата по грейдам')
ax.legend(title='Профессия')
plt.xticks(rotation=45, ha='right')

fig.tight_layout()

plt.show()

# %% [markdown]
# **Вывод по разделу 3.2.3**
#
# Предлагаемая работодателями зарплата на начальном грейде больше у вакансий "Data Scientist" (156 тыс.руб.) чем у вакансий специальности "Аналитик данных" (127 тыс.руб.). При этом к грейду Senior с требуемым опытом больше 6 лет уровень зарплаты выравниваются, но с сохранением лидирования уровня зарплаты у вакансий "Data Scientist" - 180 тыс. руб., против зарплаты у вакансий "Аналитик данных" - 178 тыс. руб.

# %% [markdown]
# #### 3.2.4. Проанализируем среднюю зарплату по работодателям и регионам

# %%
employer_counts_tot = data['employer'].value_counts().head(1) # считаем количество вакансий в разбивке по работодателям и выбираем 1, у кого больше всего вакансий
employer_counts_tot
# Out:
# employer
# СБЕР    374
# Name: count, dtype: int64

# %%
# фильтруем массив данных по выбранному работодателю
top_employers_tot = employer_counts_tot.index
df_top = data[data['employer'].isin(top_employers_tot)]
df_top.head(5)
# Out:
#            id                                         name  \
# 6   100069131                                дата аналитик
# 7   100077503                                 data analyst
# 11  100097062                                 data analyst
# 20  100301503  data analyst (команда управления комплаенс)
# 24  100306066                              аналитик данных
#
#           published_at                    alternate_url      type employer  \
# 6  2024-05-24 13:05:01  https://hh.ru/vacancy/100069131  Открытая     СБЕР
# 7  2024-05-24 14:14:00  https://hh.ru/vacancy/100077503  Открытая     СБЕР
# 11 2024-05-24 17:05:00  https://hh.ru/vacancy/100097062  Открытая     СБЕР
# 20 2024-05-27 09:05:09  https://hh.ru/vacancy/100301503  Открытая     СБЕР
# 24 2024-05-27 09:31:00  https://hh.ru/vacancy/100306066  Открытая     СБЕР
#
#             department             area           experience  \
# 6   Сбер для экспертов  Санкт-Петербург  Junior+ (1-3 years)
# 7   Сбер для экспертов           Москва   Middle (3-6 years)
# 11  Сбер для экспертов           Москва  Junior+ (1-3 years)
# 20            Сбер. IT           Москва   Middle (3-6 years)
# 24  Сбер для экспертов           Москва  Junior+ (1-3 years)
#
#                                            key_skills  ...  \
# 6   ['Документация', 'Проактивность', 'Коммуникация']  ...
# 7                                          ['Pandas']  ...
# 11                     ['confluence', 'Документация']  ...
# 20                                                 []  ...
# 24                                                 []  ...
#
#                                description_lemmatized    salary_from  \
# 6   команда данные инвестиционный продукт развиват...  126878.378378
# 7   команда data science искать руководитель напра...  136829.397516
# 11  управление зарплатной проект блок сеть продажа...  136829.397516
# 20  команда управление комплаенс искать новый data...  136829.397516
# 24  команда управление организация работа проблемн...  136829.397516
#
#         salary_to     salary_bin  key_skills_from_key_skills_field  \
# 6   166829.545455  ЗП не указана                               NaN
# 7   214055.069231  ЗП не указана                               NaN
# 11  214055.069231  ЗП не указана                               NaN
# 20  214055.069231  ЗП не указана                               NaN
# 24  214055.069231  ЗП не указана                               NaN
#
#     hard_skills_from_description               soft_skills_from_description  \
# 6                            NaN  Коммуникация, Документация, Проактивность
# 7                         Pandas                                        NaN
# 11                    confluence                               Документация
# 20                           NaN                                        NaN
# 24                           NaN                                        NaN
#
#            vac_name month    salary_mean
# 6   аналитик данных     5  146853.961916
# 7   аналитик данных     5  175442.233373
# 11  аналитик данных     5  175442.233373
# 20  аналитик данных     5  175442.233373
# 24  аналитик данных     5  175442.233373
#
# [5 rows x 23 columns]

# %%
# Создание сводной таблицы по работодателям и регионам
pivot_table_da = df_top.query('vac_name == "аналитик данных"').pivot_table(values='salary_mean', index='area', columns= 'employer', aggfunc='mean', fill_value=0).sort_values(by='СБЕР', ascending=False)
pivot_table_da.reset_index()
# Out:
# employer             area           СБЕР
# 0                  Москва  175483.840501
# 1                  Казань  163016.666667
# 2         Санкт-Петербург  145469.792032
# 3         Нижний Новгород  120604.423077
# 4                  Вельск  100000.000000
# 5            Екатеринбург   98797.222222
# 6                  Майкоп   90000.000000
# 7                  Самара   88333.333333
# 8                   Пермь   57462.500000
# 9                Адыгейск   47500.000000

# %%
# Создание сводной таблицы по работодателям и регионам
pivot_table_ds = df_top.query('vac_name == "data scientist"').pivot_table(values='salary_mean', index='area', columns= 'employer', aggfunc='mean', fill_value=0).sort_values(by='СБЕР', ascending=False)
pivot_table_ds.reset_index()
# Out:
# employer             area           СБЕР
# 0                  Москва  175571.531685
# 1         Санкт-Петербург  146853.961916
# 2             Новосибирск  139656.590909
# 3         Нижний Новгород  121536.884615
# 4            Екатеринбург   98797.222222
# 5                    Сочи   80000.000000
# 6                 Воронеж   75000.000000

# %%
fig, axs = plt.subplots(1, 2, figsize=(15, 5))

# Сортировка данных и построение графика для Аналитиков Данных
pivot_table_da.plot(kind='bar', ax=axs[0])
axs[0].set_title('Средняя зарплата по работодателям и регионам по вакансии "Аналитик Данных"')
axs[0].set_xlabel('Регион')
axs[0].set_ylabel('Средняя зарплата')
axs[0].legend(title='Работодатель')
axs[0].grid(True)

# Сортировка данных и построение графика для Data Scientist
pivot_table_ds.plot(kind='bar', ax=axs[1])
axs[1].set_title('Средняя зарплата по работодателям и регионам по вакансии "Data Scientist"')
axs[1].set_xlabel('Регион')
axs[1].set_ylabel('Средняя зарплата')
axs[1].legend(title='Работодатель')
axs[1].grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# **Вывод по разделу 3.2.4**
#
# Мы провели анализ средней зарплаты в разбивке по выбранному работадателю по регионам.
# Для анализа мы выбрали работадателя, у которого представлено больше всего вакансий - это Сбер.
# Мы видим, что самая высока зарплата как по вакансиям "Аналитик данных" так и по вакансиям "Data Scientist" -  в Москве, и уровень зарплата для обеих специальностей на уровне 175 тыс. руб. Самая низкая зарплата для вакансий "Аналитик данных" - это 47,5 тыс. руб. в Горно-Алтайске и для вакансий "Data Scientist" 75 тыс. руб. в Воронеже

# %% [markdown]
# #### 3.2.5 Пронанализируем сренюю зарплату в помесячной разбивке по грейдам

# %%
data_da.head() # выводим первые 5 строк датафрейма
# Out:
#           id                                    name        published_at  \
# 0  100039284  junior аналитик данных (исследователь) 2024-05-24 09:37:04
# 1  100039480                         аналитик данных 2024-05-24 09:39:00
# 2  100042705         аналитик данных (исследователь) 2024-05-24 10:01:25
# 3  100046788                 ведущий аналитик данных 2024-05-24 10:28:18
# 4  100056244                         аналитик данных 2024-05-24 11:27:40
#
#                      alternate_url      type           employer  \
# 0  https://hh.ru/vacancy/100039284  Открытая  DNS Головной офис
# 1  https://hh.ru/vacancy/100039480  Открытая              Комус
# 2  https://hh.ru/vacancy/100042705  Открытая  DNS Головной офис
# 3  https://hh.ru/vacancy/100046788  Открытая           Х5 Group
# 4  https://hh.ru/vacancy/100056244  Открытая             ЛУКОЙЛ
#
#                    department         area             experience  \
# 0                         NaN  Владивосток  Junior (no experince)
# 1                         NaN       Москва  Junior (no experince)
# 2                         NaN  Владивосток    Junior+ (1-3 years)
# 3  X5 GROUP, Центральный офис       Москва    Junior+ (1-3 years)
# 4                         NaN       Москва     Middle (3-6 years)
#
#                                           key_skills  ...  \
# 0              ['Power BI', 'СУБД', 'Python', 'SQL']  ...
# 1   ['MS SQL', 'Работа с базами данных', 'MS Excel']  ...
# 2  ['SQL', 'Power BI', 'СУБД', 'Python', 'Clickho...  ...
# 3  ['Анализ данных', 'Коммуникация', 'SQL', 'MS O...  ...
# 4                                   ['Документация']  ...
#
#                                          description  \
# 0  наше направление занимается повышением эффекти...
# 1  сегодня комус один из крупнейших поставщиков о...
# 2  наше направление занимается повышением эффекти...
# 3  задачи:  разработка бизнес-моделей для группов...
# 4  обязанности:  участие в проектировании, разраб...
#
#                               description_lemmatized salary_from salary_to  \
# 0  наш направление заниматься повышение эффективн...     60000.0       NaN
# 1  сегодня комус крупный поставщик офисный товар ...         NaN       NaN
# 2  наш направление заниматься повышение эффективн...     90000.0       NaN
# 3  задача разработка бизнес модель групповой прог...         NaN       NaN
# 4  обязанность участие проектирование разработка ...         NaN       NaN
#
#       salary_bin                   key_skills_from_key_skills_field  \
# 0  ЗП не указана                        SQL, Power BI, Python, СУБД
# 1  ЗП не указана           Работа с базами данных, MS SQL, MS Excel
# 2  ЗП не указана      SQL, Power BI, Python, СУБД, BPMN, Clickhouse
# 3  ЗП не указана  MS Office, SQL, Python, Hadoop, Нive, Аналитич...
# 4  ЗП не указана                                                NaN
#
#   hard_skills_from_description soft_skills_from_description         vac_name  \
# 0                          NaN                          NaN  аналитик данных
# 1                          NaN                          NaN  аналитик данных
# 2                          NaN                          NaN  аналитик данных
# 3       Pandas, Юнит-экономика                 Коммуникация  аналитик данных
# 4                          NaN                 Документация  аналитик данных
#
#   month
# 0   5.0
# 1   5.0
# 2   5.0
# 3   5.0
# 4   5.0
#
# [5 rows x 22 columns]

# %%
data['published_at']=pd.to_datetime(data['published_at']) # меняем формат данных в столбце с датой публикации вакансии

# %%
data['month']=data['published_at'].dt.month # выделяем в отдельный столбец месяц публикации вакансии

# %%
# Данные для аналитика данных
df_analyst = data.query('vac_name == "аналитик данных" and month!=2').pivot_table(
    index='month', columns='experience', values='salary_mean', aggfunc='mean'
).fillna(0).reset_index()
df_analyst
# Out:
# experience  month  Junior (no experince)  Junior+ (1-3 years)  \
# 0             3.0          141763.411800        150945.133599
# 1             4.0          128249.034699        155293.244288
# 2             5.0          121511.389688        157601.474196
#
# experience  Middle (3-6 years)  Senior (6+ years)
# 0                177565.045514           0.000000
# 1                170939.858863      181471.116687
# 2                174580.097810      175442.233373

# %%
# Данные для data scientist
df_scientist = data.query('vac_name == "data scientist" and month!=2').pivot_table(
    index='month', columns='experience', values='salary_mean', aggfunc='mean'
).fillna(0).reset_index()
df_scientist
# Out:
# experience  month  Junior (no experince)  Junior+ (1-3 years)  \
# 0             3.0          156942.842523        165259.991982
# 1             4.0          151805.705430        169925.939936
# 2             5.0          158183.489206        164210.051714
#
# experience  Middle (3-6 years)  Senior (6+ years)
# 0                174742.894368      171324.454202
# 1                175521.165301      175442.233373
# 2                175549.096791      190080.521101

# %%
# Создание графиков
plt.figure(figsize=(12, 6))

# График для аналитиков данных
plt.subplot(2, 1, 1)
for exp_level in ['Junior (no experince)', 'Junior+ (1-3 years)', 'Middle (3-6 years)','Senior (6+ years)']:
    plt.plot(df_analyst['month'], df_analyst[exp_level], label=exp_level)
plt.xlabel('Месяц')
plt.ylabel('Средняя зарплата')
plt.title('Средняя зарплата аналитиков данных в разбивке по грейдам и месяцам')
plt.legend()

# График для Data Scientist
plt.subplot(2, 1, 2)
for exp_level in ['Junior (no experince)', 'Junior+ (1-3 years)', 'Middle (3-6 years)','Senior (6+ years)']:
    plt.plot(df_scientist["month"], df_scientist[exp_level], label=exp_level)
plt.xlabel('Месяц')
plt.ylabel('Средняя зарплата')
plt.title('Средняя зарплата Data Scientist в разбивке по грейдам и месяцам')
plt.legend()

plt.tight_layout()
plt.show()

# %%
df_analyst.columns.tolist()
# Out:
# ['month',
#  'Junior (no experince)',
#  'Junior+ (1-3 years)',
#  'Middle (3-6 years)',
#  'Senior (6+ years)']

# %% [markdown]
# ### **Вывод по разделу 3.2.5**
#
# Мы провели анализ средней зарплаты по месяцам в разбивке по грейдам.
#
# *Для грейда Junior (no experience)*:
# Для вакансий "Аналитик данных" средняя зарплата в вакансиях уменьшилась в мае 2024 по сравнению с мартом 2024.
# Для вакансий "Data Scientist" в целом имелась динамика на снижение средней зарплаты, кроме апреля 2024, где мы видим рост по сравнению с другими месяцами.
#
# *Для грейда Junior+ (1-3 years)*:
# Для вакансий "Аналитик данных" средняя зарплата в вакансиях в период с марта 2024 по май 2024 находилась примерно на одном уровне 155 тыс. руб.
# Для вакансий "Data Scientist" ситуация аналогична предыдущему грейду, где мы видим скачок зарплаты до 170 тыс. руб. в апреле 2024.
#
# *Для грейда Middle (3-6 years)*:
# Для вакансий "Аналитик данных" средняя зарплата в вакансиях уменьшилась в мае 2024 по сравнению с мартом 2024.
# Для вакансий "Data Scientist" средняя зарплата примерно на одном уровне 175 тыс.руб.
#
# *Для грейда Senior (6+ years)*:
# Для вакансий "Аналитик данных" средняя зарплата в апреле выше, чем в мае 2024, вакансий за март нет.
# Для вакансий "Data Scientist" мы видим подъем средней зарплаты в мае до 190 тыс. руб. по сравнению в мартом и апрелем
#
#
#
# ### Общее наблюдение:
#
# 1. *Аналитик данных:*
#    - Видим, что средняя зарплата растет с уровнем опыта.
#    - Самая высокая зарплата у Senior аналитиков.
#    - Можно предположить, что с ростом опыта зарплата также увеличивается.
#
# 2. *Data Scientist:*
#    - Здесь также наблюдается рост зарплаты с уровнем опыта.
#    - Senior Data Scientist получают наибольшую зарплату.
#    - Возможно, опытные специалисты в этой области ценятся больше.

# %% [markdown]
# #### 3.2.6 Определение типичного места работы для вакансий "Аналитика данных" и "Data Scientist" по типу занятости

# %%
type_empl=data.groupby(['employment','vac_name']).size().reset_index(name='count') # группируем данные по типу занятости и названию вакансии
type_empl
# Out:
#             employment         vac_name  count
# 0     Полная занятость   data scientist    728
# 1     Полная занятость  аналитик данных   1382
# 2     Проектная работа   data scientist      4
# 3     Проектная работа  аналитик данных      4
# 4           Стажировка   data scientist     13
# 5           Стажировка  аналитик данных     12
# 6  Частичная занятость   data scientist      7
# 7  Частичная занятость  аналитик данных     12

# %%
type_pivot=type_empl.pivot_table(index='employment', columns='vac_name', values='count').reset_index().fillna(0) # формируем пивот
type_pivot
# Out:
# vac_name           employment  data scientist  аналитик данных
# 0            Полная занятость           728.0           1382.0
# 1            Проектная работа             4.0              4.0
# 2                  Стажировка            13.0             12.0
# 3         Частичная занятость             7.0             12.0

# %%
total_vacancies_ds = type_pivot['data scientist'].sum()# считаем общее количество вакансий
total_vacancies_ds
# Out:
# 752.0

# %%
total_vacancies_da = type_pivot['аналитик данных'].sum()# считаем общее количество вакансий
total_vacancies_da
# Out:
# 1410.0

# %%
type_pivot['data scientist, %'] = round((type_pivot['data scientist'] / total_vacancies_ds) * 100,2) # добавляем столбец с долей вакансий для специальности

# %%
type_pivot['аналитик данных, %'] = round((type_pivot['аналитик данных'] / total_vacancies_da) * 100.2) # добавляем столбец с долей вакансий для специальности

# %%
type_pivot # выводим пивот
# Out:
# vac_name           employment  data scientist  аналитик данных  \
# 0            Полная занятость           728.0           1382.0
# 1            Проектная работа             4.0              4.0
# 2                  Стажировка            13.0             12.0
# 3         Частичная занятость             7.0             12.0
#
# vac_name  data scientist, %  аналитик данных, %
# 0                     96.81                98.0
# 1                      0.53                 0.0
# 2                      1.73                 1.0
# 3                      0.93                 1.0

# %%
# Создание фигуры и осей
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 7))

# Построение первого графика для Data Scientist
ax1.bar(type_pivot['employment'], type_pivot['data scientist, %'], color='skyblue')
ax1.set_xlabel('Тип занятости')
ax1.set_ylabel('Процент вакансий')
ax1.set_title('Data Scientist, %')

# Построение второго графика для Аналитика данных
ax2.bar(type_pivot['employment'], type_pivot['аналитик данных, %'], color='lightgreen')
ax2.set_xlabel('Тип занятости')
ax2.set_ylabel('Процент вакансий')
ax2.set_title('Аналитик данных, %')

# Показ графиков
plt.tight_layout()
plt.show()

# %% [markdown]
# **Вывод по разделу 3.2.6**
#
# Мы провели анализ по типу занятости, указанной в вакансиях "Аналитик данных" и "Data scientist" за период с марта 2024 по май 2024.
# В данных имеются 4 типа занятости: полная занятость, проектная работа, стажировка и частичная занятость.
# Для обеих вакансий превалирует полная занятость и составляет в среднем 97%

# %% [markdown]
# #### 3.2.7 Определение типичного места работы для Аналитика данных и Data Scientist по Графику работы

# %%
scedul_pivot=data.pivot_table(index='schedule', columns='vac_name', values='id',aggfunc='count') # формируем пивот с графиков работы в вакансиях в разбивке по специальностям

# %%
scedul_pivot['total']=scedul_pivot['data scientist']+scedul_pivot['аналитик данных'] # считаем общее количество вакансий для 2х специальностей

# %%
scedul_pivot['ratio_ds,%']=round((scedul_pivot['data scientist']/scedul_pivot['data scientist'].sum())*100,2) # считаем долю вакансий в зависимости от типа графика

# %%
scedul_pivot['ratio_da,%']=round((scedul_pivot['аналитик данных']/scedul_pivot['аналитик данных'].sum())*100,2) # считаем долю вакансий в зависимости от типа графика

# %%
scedul_pivot.sort_values(by='total', ascending=False) # сортируем данные по общему количеству вакансий
# Out:
# vac_name          data scientist  аналитик данных  total  ratio_ds,%  \
# schedule
# Полный день                  564             1130   1694       75.00
# Удаленная работа             150              240    390       19.95
# Гибкий график                 35               33     68        4.65
# Сменный график                 3                7     10        0.40
#
# vac_name          ratio_da,%
# schedule
# Полный день            80.14
# Удаленная работа       17.02
# Гибкий график           2.34
# Сменный график          0.50

# %%
# Установка стиля для графиков
sns.set(style="whitegrid")

# Создание фигуры и осей
fig, ax1 = plt.subplots(figsize=(12, 6))

# Построение столбчатой диаграммы для количества вакансий
sns.barplot(x=scedul_pivot.index, y='total', data=scedul_pivot, ax=ax1, color='skyblue', label='Всего вакансий')

# Добавление второго графика для долей (ratio)
ax2 = ax1.twinx()
sns.lineplot(x=scedul_pivot.index, y='ratio_ds,%', data=scedul_pivot, ax=ax2, color='blue', marker='o', label='Ratio DS (%)')
sns.lineplot(x=scedul_pivot.index, y='ratio_da,%', data=scedul_pivot, ax=ax2, color='green', marker='o', label='Ratio DA (%)')

# Настройка осей и заголовков
ax1.set_xlabel('Тип графика работы')
ax1.set_ylabel('Количество вакансий')
ax2.set_ylabel('Доля (%)')
ax1.set_title('Анализ вакансий по типу графика работы')
ax1.legend(loc='upper left')
ax2.legend(loc='upper right')

# Показ графика
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Admin\anaconda4\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Admin\anaconda4\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Admin\anaconda4\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Admin\anaconda4\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# **Вывод по разделу 3.2.7**
#
# Мы провели анализ типичного места работы для Аналитика данных и Data Scientist по Графику работы.
# В целом в вакансиях представлены 4 графика работы: это полный день, гибкий график, сменный график и удаленная работа.
# Для обеих вакансий превалирует полный день, для вакансии Data Scientis составляет 74% от всех вакансий, для Аналитика данных 80% всех вакансий.
# На последнем месте по условиям найма стоит сменный график и занимает в среднем 0,5% от всех вакансий

# %% [markdown]
# ### 3.3 Определение, какие навыки спрашивают чаще - твердые или мягкие.

# %%
data.head() # выводим первые 4 строк датафрейма
# Out:
#           id                                    name        published_at  \
# 0  100039284  junior аналитик данных (исследователь) 2024-05-24 09:37:04
# 1  100039480                         аналитик данных 2024-05-24 09:39:00
# 2  100042705         аналитик данных (исследователь) 2024-05-24 10:01:25
# 3  100046788                 ведущий аналитик данных 2024-05-24 10:28:18
# 4  100056244                         аналитик данных 2024-05-24 11:27:40
#
#                      alternate_url      type           employer  \
# 0  https://hh.ru/vacancy/100039284  Открытая  DNS Головной офис
# 1  https://hh.ru/vacancy/100039480  Открытая              Комус
# 2  https://hh.ru/vacancy/100042705  Открытая  DNS Головной офис
# 3  https://hh.ru/vacancy/100046788  Открытая           Х5 Group
# 4  https://hh.ru/vacancy/100056244  Открытая             ЛУКОЙЛ
#
#                    department         area             experience  \
# 0                         NaN  Владивосток  Junior (no experince)
# 1                         NaN       Москва  Junior (no experince)
# 2                         NaN  Владивосток    Junior+ (1-3 years)
# 3  X5 GROUP, Центральный офис       Москва    Junior+ (1-3 years)
# 4                         NaN       Москва     Middle (3-6 years)
#
#                                           key_skills  ...  \
# 0              ['Power BI', 'СУБД', 'Python', 'SQL']  ...
# 1   ['MS SQL', 'Работа с базами данных', 'MS Excel']  ...
# 2  ['SQL', 'Power BI', 'СУБД', 'Python', 'Clickho...  ...
# 3  ['Анализ данных', 'Коммуникация', 'SQL', 'MS O...  ...
# 4                                   ['Документация']  ...
#
#                               description_lemmatized    salary_from  \
# 0  наш направление заниматься повышение эффективн...   60000.000000
# 1  сегодня комус крупный поставщик офисный товар ...  136829.397516
# 2  наш направление заниматься повышение эффективн...   90000.000000
# 3  задача разработка бизнес модель групповой прог...  136829.397516
# 4  обязанность участие проектирование разработка ...  136829.397516
#
#        salary_to     salary_bin  \
# 0  119713.333333  ЗП не указана
# 1  214055.069231  ЗП не указана
# 2  119713.333333  ЗП не указана
# 3  214055.069231  ЗП не указана
# 4  214055.069231  ЗП не указана
#
#                     key_skills_from_key_skills_field  \
# 0                        SQL, Power BI, Python, СУБД
# 1           Работа с базами данных, MS SQL, MS Excel
# 2      SQL, Power BI, Python, СУБД, BPMN, Clickhouse
# 3  MS Office, SQL, Python, Hadoop, Нive, Аналитич...
# 4                                                NaN
#
#    hard_skills_from_description soft_skills_from_description         vac_name  \
# 0                           NaN                          NaN  аналитик данных
# 1                           NaN                          NaN  аналитик данных
# 2                           NaN                          NaN  аналитик данных
# 3        Pandas, Юнит-экономика                 Коммуникация  аналитик данных
# 4                           NaN                 Документация  аналитик данных
#
#   month    salary_mean
# 0   5.0   89856.666667
# 1   5.0  175442.233373
# 2   5.0  104856.666667
# 3   5.0  175442.233373
# 4   5.0  175442.233373
#
# [5 rows x 23 columns]

# %%
list_skills=list(data_da['key_skills_from_key_skills_field'].unique()) # формируем список всех уникальных значений в столбце со скиллами

# %%
# разделяем список на отдельные значения
all_values = []
for i in list_skills:
    if isinstance(i, str):
        all_values.extend(i.split(', '))

# %%
# считаем частоту повторения скиллов из списка и формируем датафрейм из 100 самых популярных скиллов
frequency = Counter(all_values)
df_frequency=pd.DataFrame(frequency.items(),columns=['skill','frequency'])
skills_to_analyse=df_frequency.sort_values(by='frequency', ascending=False).head(100)
skills_to_analyse
# Out:
#                          skill  frequency
# 0                          SQL        415
# 2                       Python        311
# 19               Анализ данных        249
# 32      Аналитическое мышление        145
# 1                     Power BI        141
# ..                         ...        ...
# 51               WEB аналитика          5
# 241  Аналитические способности          5
# 118                   Superset          5
# 282                         1С          5
# 76                  Qlik Sense          5
#
# [100 rows x 2 columns]

# %%
skills_to_analyse['skill'].unique() # выводим все уникальные скиллы
# Out:
# array(['SQL', 'Python', 'Анализ данных', 'Аналитическое мышление',
#        'Power BI', 'MS Excel', 'Работа с базами данных',
#        'Работа с большим объемом информации', 'Аналитика',
#        'Data Analysis', 'MS SQL', 'Базы данных',
#        'Аналитические исследования', 'Tableau',
#        'Математическая статистика', 'Сбор и анализ информации',
#        'PostgreSQL', 'Big Data', 'Статистический анализ', 'MS PowerPoint',
#        'ETL', 'Бизнес-анализ', 'Анализ бизнес показателей',
#        'Прогнозирование', 'Английский язык', 'Подготовка презентаций',
#        'Hadoop', 'MS Power BI', 'Математический анализ',
#        'Визуализация данных', 'PowerBI', 'Сводные таблицы', 'VBA',
#        'A/B тесты', 'Pandas', 'BI', 'Excel', 'Spark', 'Power Query',
#        'Деловая коммуникация', 'Анализ рынка', 'Работа в команде', 'Git',
#        'Подготовка отчетов', 'DWH', 'Аналитический склад ума',
#        'Google Analytics', 'Маркетинговый анализ', 'Machine Learning',
#        'Numpy', 'Airflow', 'ML', 'DAX', 'ORACLE', 'Clickhouse', 'BPMN',
#        'ClickHouse', 'Data Science', 'Управленческая отчетность',
#        'Аналитика продаж', 'СУБД', 'Математическое моделирование',
#        'Работа с системами аналитики', 'ВПР', 'Деловая переписка',
#        'Грамотная речь', 'Оптимизация бизнес-процессов',
#        'Машинное обучение', 'API', 'Финансовый анализ', 'Greenplum',
#        'Системный анализ', 'Яндекс.Метрика', 'PyTorch',
#        'Экономический анализ', 'Power Pivot',
#        'Разработка технических заданий', 'Статистика', 'UML',
#        'Анализ ассортиментной линейки', 'Обучение и развитие', 'pandas',
#        'Системное мышление', 'Google Docs', 'Ad Hoc Analysis', 'R', 'NLP',
#        'Навыки презентации', 'Торговая площадка',
#        'Точность и внимательность к деталям', 'Автоматизация процессов',
#        'Grafana', 'Финансовая отчетность', 'Управление проектами',
#        'Конкурентная аналитика', 'WEB аналитика',
#        'Аналитические способности', 'Superset', '1С', 'Qlik Sense'],
#       dtype=object)

# %%
# формируем список софт скиллов
soft_skills={'Аналитическое мышление','Работа в команде','Деловая коммуникация','Работа с большим объемом информации','Аналитический склад ума','Управление командой','Управление рисками','Системное мышление','Умение принимать решения','Обучение и развитие'}

# %%
# пишем функцию для определения принодлежности скилла к хардовому или софтовому
def skill_type(skill):
    if skill in soft_skills:
        return 'soft'
    else:
        return 'hard'

# %%
# применяем функцию к датафрейму
skills_to_analyse['type']=skills_to_analyse['skill'].apply(skill_type)
skills_to_analyse
# Out:
#                          skill  frequency  type
# 0                          SQL        415  hard
# 2                       Python        311  hard
# 19               Анализ данных        249  hard
# 32      Аналитическое мышление        145  soft
# 1                     Power BI        141  hard
# ..                         ...        ...   ...
# 51               WEB аналитика          5  hard
# 241  Аналитические способности          5  hard
# 118                   Superset          5  hard
# 282                         1С          5  hard
# 76                  Qlik Sense          5  hard
#
# [100 rows x 3 columns]

# %%
# считаем количество хардовых и софтовых скиллов в требованиях к вакансиям "Аналитика данных" 
skills_visual=skills_to_analyse.pivot_table(index='type', values='skill', aggfunc='count').reset_index()
skills_visual
# Out:
#    type  skill
# 0  hard     93
# 1  soft      7

# %%
list_skills_ds=list(data_ds['key_skills_from_key_skills_field'].unique()) # формируем список всех уникальных значений в столбце со скиллами для вакансий дата сайнтиста

# %%
# разделяем список на отдельные значения
all_values_ds = []
for i in list_skills_ds:
    if isinstance(i, str):
        all_values_ds.extend(i.split(', '))

# %%
# считаем частоту повторения скиллов из списка и формируем датафрейм из 100 самых популярных скиллов
frequency_ds = Counter(all_values_ds)
df_frequency_ds=pd.DataFrame(frequency_ds.items(),columns=['skill','frequency'])
skills_to_analyse_ds=df_frequency_ds.sort_values(by='frequency', ascending=False).head(100)
skills_to_analyse_ds
# Out:
#                             skill  frequency
# 3                          Python        224
# 0                             SQL        131
# 6                Machine Learning         73
# 14                             ML         60
# 18                   Data Science         43
# ..                            ...        ...
# 129                 Моделирование          2
# 160                        Golang          2
# 188       искусственный интеллект          2
# 157  Алгоритмы и структуры данных          2
# 156                        ORACLE          2
#
# [100 rows x 2 columns]

# %%
skills_to_analyse_ds['skill'].unique() # выводим все уникальные скиллы
# Out:
# array(['Python', 'SQL', 'Machine Learning', 'ML', 'Data Science',
#        'Математическая статистика', 'PyTorch', 'Pandas', 'Анализ данных',
#        'NLP', 'Big Data', 'Git', 'Data Analysis', 'Машинное обучение',
#        'Spark', 'Математическое моделирование', 'Docker', 'Linux',
#        'Английский язык', 'Статистический анализ',
#        'Аналитическое мышление', 'PostgreSQL', 'Hadoop', 'Deep Learning',
#        'Numpy', 'Математический анализ', 'Работа с базами данных',
#        'MS SQL', 'LLM', 'Базы данных', 'Airflow', 'Data Mining', 'IT',
#        'Аналитические исследования', 'numpy', 'sklearn',
#        'Computer Vision', 'CV', 'PySpark', 'Tensorflow', 'ClickHouse',
#        'Scikit-learn', 'Прогнозирование', 'Hive', 'TensorFlow',
#        'data science', 'NumPy', 'Kubernetes', 'pandas', 'ETL',
#        'A/B тесты', 'Разработка поисковых технологий', 'MySQL',
#        'Machine learning', 'OpenCV', 'Power BI', 'MLFlow',
#        'Работа с большим объемом информации', 'Data Scientist', 'MLflow',
#        'LGD', 'PD', 'C++', 'Keras', 'Статистика', 'Data science', 'Redis',
#        'Kafka', 'Clickhouse', 'RecSys', 'API', 'ИИ', 'AI',
#        'кредитные риски', 'машинное обучение', 'OCR', 'Работа в команде',
#        'Портфельные риски', 'DL', 'MongoDB', 'plotly', 'DVC',
#        'Mathematical Statistics', 'Sas', 'Pytorch', 'RAG', 'REST API',
#        'Модельный риск', 'Yandex Cloud Platform', 'Валидация моделей',
#        'Аналитика', 'Atlassian Jira', 'a/b-experiments', 'C/C++', 'Java',
#        'Моделирование', 'Golang', 'искусственный интеллект',
#        'Алгоритмы и структуры данных', 'ORACLE'], dtype=object)

# %%
skills_to_analyse_ds['type']=skills_to_analyse_ds['skill'].apply(skill_type) # применяем функцию к датафрейму для классификации скиллов на твердые и мягкие
skills_to_analyse_ds
# Out:
#                             skill  frequency  type
# 3                          Python        224  hard
# 0                             SQL        131  hard
# 6                Machine Learning         73  hard
# 14                             ML         60  hard
# 18                   Data Science         43  hard
# ..                            ...        ...   ...
# 129                 Моделирование          2  hard
# 160                        Golang          2  hard
# 188       искусственный интеллект          2  hard
# 157  Алгоритмы и структуры данных          2  hard
# 156                        ORACLE          2  hard
#
# [100 rows x 3 columns]

# %%
skills_visual_ds = skills_to_analyse_ds.pivot_table(index='type', values='skill', aggfunc='count').reset_index() # считаем количество хардовых и софтовых скиллов в требованиях к вакансиям "Data scientist" 
skills_visual_ds
# Out:
#    type  skill
# 0  hard     97
# 1  soft      3

# %%
# Установка стиля для графиков
sns.set(style="whitegrid")

# Создание фигуры и осей
fig, axs = plt.subplots(1, 2, figsize=(15, 5))

# Построение круговой диаграммы для Аналитика данных
axs[0].pie(skills_visual['skill'], labels=skills_visual['type'], autopct='%1.1f%%', startangle=140, colors=sns.color_palette('viridis', len(skills_visual)))
axs[0].set_title('Количество навыков по типам для вакансии "Аналитик данных"')

# Построение круговой диаграммы для Data Scientist
axs[1].pie(skills_visual_ds['skill'], labels=skills_visual_ds['type'], autopct='%1.1f%%', startangle=140, colors=sns.color_palette('viridis', len(skills_visual_ds)))
axs[1].set_title('Количество навыков по типам для вакансии "Data Scientist"')

# Показ графиков
plt.tight_layout()
plt.show()

# %% [markdown]
# **Вывод по разделу 3.3**
#
# Мы провели анализ требуемых работодателями скиллов для обоих вакансий. В результате анализа выявлено, что для вакансий "Аналитик данных" из 100 проанализированных скиллов 7% - это софт скиллы, а 93% это хард скиллы. Приблизительно такая же картина для вакансий "Data Scientist". 3% - это софт скиллы и 97% - это хард скиллы.

# %% [markdown]
# ### 3.4 К какому грейду и к какой специальности требований больше.

# %%
data['count']=data['key_skills_from_key_skills_field'].astype(str).apply(lambda x:len(x.split(','))) # считаем количество значений в столбце со скиллами

# %%
data.pivot_table(index='experience', columns = 'vac_name', values='count',aggfunc='mean').reset_index() # формируем сводную таблицу со средним требованием к вакансиям в разбивке по грейдам
# Out:
# vac_name             experience  data scientist  аналитик данных
# 0         Junior (no experince)        2.648649         3.398148
# 1           Junior+ (1-3 years)        3.547904         4.272941
# 2            Middle (3-6 years)        3.669468         4.337104
# 3             Senior (6+ years)        5.375000         7.100000

# %% [markdown]
# **Вывод по разделу 3.4**
#
# Мы проанлизировали к какому грейду и к какой специальности требований больше.
# В результате анализа выявлено, что больше всего требований для обеих вакансий к грейду Senior (6+ years) и  меньше всего к Junior (no experince), что в целом является достаточно логичным.

# %% [markdown]
# ### 3.5 Определение наиболее желаемых кандидатов на вакансии Аналитик данных и Data Scientist по следующим параметрам: самые важные hard-skils, самые важные soft-skils. Ответ отдельно дайте для грейдов Junior, Junior+, Middle, Senior.

# %%
data.head() # выводим первый 5 строк датафрейма
# Out:
#           id                                    name        published_at  \
# 0  100039284  junior аналитик данных (исследователь) 2024-05-24 09:37:04
# 1  100039480                         аналитик данных 2024-05-24 09:39:00
# 2  100042705         аналитик данных (исследователь) 2024-05-24 10:01:25
# 3  100046788                 ведущий аналитик данных 2024-05-24 10:28:18
# 4  100056244                         аналитик данных 2024-05-24 11:27:40
#
#                      alternate_url      type           employer  \
# 0  https://hh.ru/vacancy/100039284  Открытая  DNS Головной офис
# 1  https://hh.ru/vacancy/100039480  Открытая              Комус
# 2  https://hh.ru/vacancy/100042705  Открытая  DNS Головной офис
# 3  https://hh.ru/vacancy/100046788  Открытая           Х5 Group
# 4  https://hh.ru/vacancy/100056244  Открытая             ЛУКОЙЛ
#
#                    department         area             experience  \
# 0                         NaN  Владивосток  Junior (no experince)
# 1                         NaN       Москва  Junior (no experince)
# 2                         NaN  Владивосток    Junior+ (1-3 years)
# 3  X5 GROUP, Центральный офис       Москва    Junior+ (1-3 years)
# 4                         NaN       Москва     Middle (3-6 years)
#
#                                           key_skills  ...    salary_from  \
# 0              ['Power BI', 'СУБД', 'Python', 'SQL']  ...   60000.000000
# 1   ['MS SQL', 'Работа с базами данных', 'MS Excel']  ...  136829.397516
# 2  ['SQL', 'Power BI', 'СУБД', 'Python', 'Clickho...  ...   90000.000000
# 3  ['Анализ данных', 'Коммуникация', 'SQL', 'MS O...  ...  136829.397516
# 4                                   ['Документация']  ...  136829.397516
#
#        salary_to     salary_bin  \
# 0  119713.333333  ЗП не указана
# 1  214055.069231  ЗП не указана
# 2  119713.333333  ЗП не указана
# 3  214055.069231  ЗП не указана
# 4  214055.069231  ЗП не указана
#
#                     key_skills_from_key_skills_field  \
# 0                        SQL, Power BI, Python, СУБД
# 1           Работа с базами данных, MS SQL, MS Excel
# 2      SQL, Power BI, Python, СУБД, BPMN, Clickhouse
# 3  MS Office, SQL, Python, Hadoop, Нive, Аналитич...
# 4                                                NaN
#
#    hard_skills_from_description  soft_skills_from_description  \
# 0                           NaN                           NaN
# 1                           NaN                           NaN
# 2                           NaN                           NaN
# 3        Pandas, Юнит-экономика                  Коммуникация
# 4                           NaN                  Документация
#
#           vac_name month    salary_mean count
# 0  аналитик данных   5.0   89856.666667     4
# 1  аналитик данных   5.0  175442.233373     3
# 2  аналитик данных   5.0  104856.666667     6
# 3  аналитик данных   5.0  175442.233373    13
# 4  аналитик данных   5.0  175442.233373     1
#
# [5 rows x 24 columns]

# %%
# Формируем функцию для определения типа навыка
def skill_type(skill):
    hard_skills = {'SQL', 'Python', 'Анализ данных', 'Аналитическое мышление', 'Power BI' 'MS Excel', 
                   'Работа с большим объемом информации', 'Machine Learning', 'ML', 'Data Science'  'Математическая статистика', 'NLP'}
    soft_skills={'Аналитическое мышление','Работа в команде','Деловая коммуникация','Работа с большим объемом информации','Аналитический склад ума',
                'Управление командой','Управление рисками','Системное мышление','Умение принимать решения','Обучение и развитие'}
    
    if skill in hard_skills:
        return 'hard'
    elif skill in soft_skills:
        return 'soft'
    else:
        return 'unknown'

# Формируем функцию для извлечения топ-скиллов
def extract_top_skills(grade, roles):
    result_df = pd.DataFrame()
    
    for role in roles:
        # Фильтрация данных по заданной вакансии и грейду
        role_data = data[data['vac_name'] == role]
        grade_data = role_data[role_data['experience'] == grade]
        
        # Обработка значений в колонке skills_column
        all_values_ds = []
        for i in grade_data['key_skills_from_key_skills_field']:
            if isinstance(i, str):
                all_values_ds.extend(i.split(', '))
        
        # Подсчет частоты встречания скиллов
        skill_counts = Counter(all_values_ds)
        
        # Преобразование в DataFrame
        skills_df = pd.DataFrame(skill_counts.items(), columns=['skill', 'count'])
        skills_df['type'] = skills_df['skill'].apply(skill_type)
        
        # Получение топ-5 хард и софт скиллов
        top_hard_skills = skills_df[skills_df['type'] == 'hard'].sort_values(by='count', ascending=False).head(5)
        top_soft_skills = skills_df[skills_df['type'] == 'soft'].sort_values(by='count', ascending=False).head(5)
        
        # Добавление данных в результирующий DataFrame
        top_hard_skills['role'] = role
        top_hard_skills['grade'] = grade
        top_soft_skills['role'] = role
        top_soft_skills['grade'] = grade
        
        result_df = pd.concat([result_df, top_hard_skills, top_soft_skills])
    
    return result_df

# %%
roles = ['data scientist', 'аналитик данных']
grades = ['Junior (no experince)', 'Junior+ (1-3 years)', 'Middle (3-6 years)','Senior (6+ years)']

# %%
# Создание фигуры и осей
fig, axs = plt.subplots(len(grades), len(roles), figsize=(15, 15))

# Построение горизонтальных столбчатых диаграмм для каждого грейда и роли
for i, grade in enumerate(grades):
    for j, role in enumerate(roles):
        top_skills = extract_top_skills(grade, [role])
        hard_skills = top_skills[top_skills['type'] == 'hard']
        soft_skills = top_skills[top_skills['type'] == 'soft']
        
        # Построение горизонтальной столбчатой диаграммы для хард скиллов
        axs[i, j].barh(hard_skills['skill'], hard_skills['count'], color='skyblue', label='Hard Skills')
        
        # Построение горизонтальной столбчатой диаграммы для софт скиллов
        axs[i, j].barh(soft_skills['skill'], soft_skills['count'], color='lightgreen', label='Soft Skills')
        
        axs[i, j].set_title(f'{role} ({grade})')
        axs[i, j].legend()
            
# Показ графиков
plt.tight_layout()
plt.show()

# %%
# Вывод списков топ-скиллов для каждой роли и грейда
for grade in grades:
    for role in roles:
        top_skills = extract_top_skills(grade, [role])
        hard_skills = top_skills[top_skills['type'] == 'hard']
        soft_skills = top_skills[top_skills['type'] == 'soft']
        
        print(f"\nТоп хард скилы для {role} ({grade}):")
        for skill in hard_skills['skill']:
            print(f"- {skill}")
        
        print(f"\nТоп софт скилы для {role} ({grade}):")
        for skill in soft_skills['skill']:
            print(f"- {skill}")
# Out:
# Топ хард скилы для data scientist (Junior (no experince)):
# - Python
# - Machine Learning
# - Анализ данных
# - ML
# - SQL
#
# Топ софт скилы для data scientist (Junior (no experince)):
# - Обучение и развитие
#
# Топ хард скилы для аналитик данных (Junior (no experince)):
# - SQL
# - Python
# - Анализ данных
# - Аналитическое мышление
# - Работа с большим объемом информации
#
# Топ софт скилы для аналитик данных (Junior (no experince)):
# - Работа в команде
# - Деловая коммуникация
# - Аналитический склад ума
# - Обучение и развитие
#
# Топ хард скилы для data scientist (Junior+ (1-3 years)):
# - Python
# - SQL
# - Machine Learning
# - ML
# - NLP
#
# Топ софт скилы для data scientist (Junior+ (1-3 years)):
# - Работа в команде
# - Управление рисками
# - Аналитический склад ума
# - Деловая коммуникация
#
# Топ хард скилы для аналитик данных (Junior+ (1-3 years)):
# - SQL
# - Python
# - Анализ данных
# - Аналитическое мышление
# - Работа с большим объемом информации
#
# Топ софт скилы для аналитик данных (Junior+ (1-3 years)):
# - Деловая коммуникация
# - Аналитический склад ума
# - Работа в команде
# - Умение принимать решения
# - Обучение и развитие
#
# Топ хард скилы для data scientist (Middle (3-6 years)):
# - Python
# - SQL
# - ML
# - Machine Learning
# - NLP
#
# Топ софт скилы для data scientist (Middle (3-6 years)):
# - Работа в команде
# - Управление рисками
# - Деловая коммуникация
#
# Топ хард скилы для аналитик данных (Middle (3-6 years)):
# - SQL
# - Python
# - Анализ данных
# - Аналитическое мышление
# - Работа с большим объемом информации
#
# Топ софт скилы для аналитик данных (Middle (3-6 years)):
# - Системное мышление
# - Деловая коммуникация
# - Обучение и развитие
# - Работа в команде
# - Управление командой
#
# Топ хард скилы для data scientist (Senior (6+ years)):
# - Python
# - ML
# - Machine Learning
# - Анализ данных
# - SQL
#
# Топ софт скилы для data scientist (Senior (6+ years)):
# - Управление командой
#
# Топ хард скилы для аналитик данных (Senior (6+ years)):
# - Python
# - SQL
# - Machine Learning
# - Аналитическое мышление
# - Анализ данных
#
# Топ софт скилы для аналитик данных (Senior (6+ years)):

# %% [markdown]
# **Вывод по разделу 3.5**
#
# ### Сравнение вакансий "Аналитик данных" и "Data Scientist" по важным навыкам
#
# #### Junior (no experience)
#
# *Data Scientist:*
# - *Hard skills:* Python, Machine Learning, ML, SQL, Анализ данных
# - *Soft skills:* Обучение и развитие
#
# *Аналитик данных:*
# - *Hard skills:* SQL, Python, Анализ данных, Аналитическое мышление, Работа с большим объемом информации
# - *Soft skills:* Работа в команде, Деловая коммуникация, Аналитический склад ума, Обучение и развитие
#
# *Выводы и наблюдения:*
# - Для обеих вакансий важны навыки Python и Анализ данных.
# - Data Scientist требует специфических навыков в области Machine Learning и ML, тогда как Аналитик данных акцентирует внимание на Аналитическом мышлении и работе с большим объемом информации.
# - Важные софт скиллы для Data Scientist включают Обучение и развитие, в то время как для Аналитика данных важны также Работа в команде и Деловая коммуникация.
#
# #### Junior+ (1-3 years)
#
# *Data Scientist:*
# - *Hard skills:* Python, SQL, Machine Learning, ML, NLP
# - *Soft skills:* Работа в команде, Аналитический склад ума, Управление рисками, Деловая коммуникация
#
# *Аналитик данных:*
# - *Hard skills:* SQL, Python, Анализ данных, Аналитическое мышление, Работа с большим объемом информации
# - *Soft skills:* Деловая коммуникация, Аналитический склад ума, Работа в команде, Умение принимать решения, Системное мышление
#
# *Выводы и наблюдения:*
# - Оба направления требуют навыков Python и SQL.
# - Data Scientist требует дополнительных навыков в области NLP и управления рисками.
# - Аналитик данных акцентирует внимание на Умении принимать решения и Системном мышлении.
#
# #### Middle (3-6 years)
#
# *Data Scientist:*
# - *Hard skills:* Python, SQL, ML, Machine Learning, NLP
# - *Soft skills:* Управление командой, Работа в команде, Обучение и развитие, Управление рисками, Деловая коммуникация
#
# *Аналитик данных:*
# - *Hard skills:* SQL, Python, Анализ данных, Аналитическое мышление, Работа с большим объемом информации
# - *Soft skills:* Системное мышление, Работа в команде, Обучение и развитие, Деловая коммуникация, Управление командой
#
# *Выводы и наблюдения:*
# - Оба направления требуют навыков Python и SQL.
# - Data Scientist требует навыков NLP и управления рисками.
# - Аналитик данных акцентирует внимание на Системном мышлении и управлении командой.
#
# #### Senior (6+ years)
#
# *Data Scientist:*
# - *Hard skills:* Python, SQL, Анализ данных, ML, Machine Learning
# - *Soft skills:* Управление командой, Управление рисками
#
# *Аналитик данных:*
# - *Hard skills:* SQL, Python, Machine Learning, Аналитическое мышление, Анализ данных
# - *Soft skills:* Управление командой, Управление рисками
#
# *Выводы и наблюдения:*
# - Для обеих вакансий важны навыки Python, SQL и Анализ данных.
# - Оба направления требуют навыков Machine Learning и управления командой.
# - Важные софт скиллы для обеих вакансий включают Управление рисками.
#
# ### Общие выводы:
# - Python и SQL являются ключевыми навыками для обеих вакансий на всех уровнях.
# - Data Scientist требует более специфических навыков в области Machine Learning и NLP.
# - Аналитик данных акцентирует внимание на Аналитическом мышлении и работе с большим объемом информации.
# - Софт скиллы, такие как Работа в команде и Деловая коммуникация, важны для обеих вакансий, но для Data Scientist также важны навыки управления рисками.

# %% [markdown]
# ### 3.6 Расчет помесячной динамики количества вакансий для Аналитика данных и Data Scientist.

# %%
data_da.head(5)
# Out:
#           id                                    name        published_at  \
# 0  100039284  junior аналитик данных (исследователь) 2024-05-24 09:37:04
# 1  100039480                         аналитик данных 2024-05-24 09:39:00
# 2  100042705         аналитик данных (исследователь) 2024-05-24 10:01:25
# 3  100046788                 ведущий аналитик данных 2024-05-24 10:28:18
# 4  100056244                         аналитик данных 2024-05-24 11:27:40
#
#                      alternate_url      type           employer  \
# 0  https://hh.ru/vacancy/100039284  Открытая  DNS Головной офис
# 1  https://hh.ru/vacancy/100039480  Открытая              Комус
# 2  https://hh.ru/vacancy/100042705  Открытая  DNS Головной офис
# 3  https://hh.ru/vacancy/100046788  Открытая           Х5 Group
# 4  https://hh.ru/vacancy/100056244  Открытая             ЛУКОЙЛ
#
#                    department         area             experience  \
# 0                         NaN  Владивосток  Junior (no experince)
# 1                         NaN       Москва  Junior (no experince)
# 2                         NaN  Владивосток    Junior+ (1-3 years)
# 3  X5 GROUP, Центральный офис       Москва    Junior+ (1-3 years)
# 4                         NaN       Москва     Middle (3-6 years)
#
#                                           key_skills  ...  \
# 0              ['Power BI', 'СУБД', 'Python', 'SQL']  ...
# 1   ['MS SQL', 'Работа с базами данных', 'MS Excel']  ...
# 2  ['SQL', 'Power BI', 'СУБД', 'Python', 'Clickho...  ...
# 3  ['Анализ данных', 'Коммуникация', 'SQL', 'MS O...  ...
# 4                                   ['Документация']  ...
#
#                                          description  \
# 0  наше направление занимается повышением эффекти...
# 1  сегодня комус один из крупнейших поставщиков о...
# 2  наше направление занимается повышением эффекти...
# 3  задачи:  разработка бизнес-моделей для группов...
# 4  обязанности:  участие в проектировании, разраб...
#
#                               description_lemmatized salary_from salary_to  \
# 0  наш направление заниматься повышение эффективн...     60000.0       NaN
# 1  сегодня комус крупный поставщик офисный товар ...         NaN       NaN
# 2  наш направление заниматься повышение эффективн...     90000.0       NaN
# 3  задача разработка бизнес модель групповой прог...         NaN       NaN
# 4  обязанность участие проектирование разработка ...         NaN       NaN
#
#       salary_bin                   key_skills_from_key_skills_field  \
# 0  ЗП не указана                        SQL, Power BI, Python, СУБД
# 1  ЗП не указана           Работа с базами данных, MS SQL, MS Excel
# 2  ЗП не указана      SQL, Power BI, Python, СУБД, BPMN, Clickhouse
# 3  ЗП не указана  MS Office, SQL, Python, Hadoop, Нive, Аналитич...
# 4  ЗП не указана                                                NaN
#
#   hard_skills_from_description soft_skills_from_description         vac_name  \
# 0                          NaN                          NaN  аналитик данных
# 1                          NaN                          NaN  аналитик данных
# 2                          NaN                          NaN  аналитик данных
# 3       Pandas, Юнит-экономика                 Коммуникация  аналитик данных
# 4                          NaN                 Документация  аналитик данных
#
#   month
# 0   5.0
# 1   5.0
# 2   5.0
# 3   5.0
# 4   5.0
#
# [5 rows x 22 columns]

# %%
pivot_da = data_da.pivot_table(index='month', columns='experience', values='id', aggfunc='count').fillna(0) # создание сводной таблицы
pivot_da
# Out:
# experience  Junior (no experince)  Junior+ (1-3 years)  Middle (3-6 years)  \
# month
# 3.0                            10                  166                  72
# 4.0                            43                  273                 129
# 5.0                            42                  352                 189
#
# experience  Senior (6+ years)
# month
# 3.0                         1
# 4.0                         4
# 5.0                         5

# %%
pivot_ds = data_ds.pivot_table(index='month', columns='experience', values='id', aggfunc='count').fillna(0) # создание сводной таблицы
pivot_ds
# Out:
# experience  Junior (no experince)  Junior+ (1-3 years)  Middle (3-6 years)  \
# month
# 3                               9                  121                 127
# 4                              21                  142                 146
# 5                               7                   71                  84
#
# experience  Senior (6+ years)
# month
# 3                           9
# 4                          10
# 5                           5

# %%
# Создание фигуры и осей для двух графиков
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18, 6))

# Построение первого графика
pivot_da.plot(ax=ax1)
ax1.set_xlabel('Месяц')
ax1.set_ylabel('Количество вакансий')
ax1.set_title('Помесячное распределение количества вакансий Аналитика данных в разбивке по грейдам')

# Построение второго графика
pivot_ds.plot(ax=ax2)
ax2.set_xlabel('Месяц')
ax2.set_ylabel('Количество вакансий')
ax2.set_title('Помесячное распределение количества вакансий Data Scientist в разбивке по грейдам')

# Отображение графиков
plt.tight_layout()
plt.show()

# %% [markdown]
# **Вывод по разделу 3.6**
#
# Мы провели расчет помесячной динамики количества вакансий для Аналитика данных и Data Scientist за период с марта 2024 по май 2024.
# В результате анализа выявлено, что в целом больше всего вакансий для грейда Junior+ (1-3 years) специальности "Аналитик данных" и грейда Middle (3-6 years) специальности "Data Scientist".
# Для вакансий "Аналитик данных" мы видим пик количества вакансий в мае 2024.
# Для вакансий "Data Scientist" мы видим пик вакансий в апреле 2024 года.

# %% [markdown]
# # 4. Выводы

# %% [markdown]
# ## *1. Загрузка данных выполнена успешно.*
#
# ## *2. Проведена предобработка данных.*
#
# ### 2.1. Мы проверили пропуски в данных.
# Критичные пропуски выявлены в столбцах с зарплатой, замена будет выполнена в следующих разделах.
#
# ### 2.2. Мы проверили данные на наличие дубликатов.
# Явных дубликатов не выявлено. В целом выявлены вакансии, в которых полностью совпадают значения в полях employer, name, key_skills, description. При этом существуют различия в дате публикации, что говорит о том, что выявленные строки не являются дубликатами, так как вакансии могли быть опубликованы повторно по причинам необходимости новых сотрудников с аналогичными требованиями.
#
# ### Дополнительно определим минимальную и максимальную даты датасета и ограничили выборку период с 01.03.2024 по 31.05.2024
#
# #### Мы ограничили массив периодом с марта по мая 2024 года
#
# ## *3. Проведен исследовательский анализ данных.*
#
# ### 3.1. Мы провели анализ вакансий в разбивке по грейдам специальностей "Аналитик данных" и "Data Scientist".
#
# На основании графиков мы видим, что для вакансий "Аналитик данных" требуется большего всего специалистов грейда Junior+ (1-3 years),  а именно 60%.
# При этом для вакансий "Data Scientist" большего всего требуется специалистов грейда Middle (3-6 years), а именно 47,5%. На втором месте по необходимости для вакансий "Data Scientist" специалисты грейда Junior+ (1-3 years), таких вакансий 44,4%
#
# #### 3.2.1. Мы проанализировали помесячную динамику вакансий "Аналитик данных" и "Data Scientist" в разбивке по работодателям за период с февраля 2024 по июнь 2024.
#
# Мы проанлизировали помесячную динамику вакансий "Аналитик данных" и "Data Scientist" в разбивке по работодателям за период с марта по май 2024.
#
# Во первых на графике мы видим, что в не зависимости от специальности больше всего вакансий у Сбера.
# Количество вакансий "Аналитика данных" достигает пика в мае, при этом, если говорить про вакансии "Data Scientist", то мы видим рост в апреле и уменьшение количества в маю.
#
# Количество вакансий "Аналитика данных" компании Озон для вакансии Аналитика данных повторяет динамику Сбера. При этом вакансии компаний WILDBERRIES	и Банк ВТБ (ПАО) показывают рост с марта по май 2024 года.
#
# Если говорить про вакансии "Data Scientist", то в топ работодателей попали такие компании как Ozon, Samokat.tech, Газпромбанк и Т1. Вакансии копаний Ozon и Газпромбанк в целом повторяют динамику Сбера
#
# **Вот несколько возможных причин для наблюдаемых тенденций:**
#
# 1. *Сезонные колебания*: Вакансии могут увеличиваться или уменьшаться в зависимости от времени года. Например, компании могут активно нанимать весной, чтобы подготовиться к летним проектам, а затем снижать активность найма к лету.
#
# 2. *Проектные циклы*: Вакансии могут быть связаны с конкретными проектами, которые имеют свои временные рамки. Например, завершение одного проекта и начало другого может влиять на количество вакансий.
#
# 3. *Экономические факторы*: Изменения в экономике, такие как рост или спад, могут влиять на количество вакансий. Компании могут увеличивать найм в периоды экономического роста и сокращать его в периоды спада.
#
# 4. *Конкуренция на рынке труда*: Компании могут активно нанимать, чтобы опередить конкурентов в привлечении талантов. Это может объяснить, почему такие компании, как Сбер и Озон, показывают схожие тенденции.
#
# 5. *Внутренние изменения в компаниях*: Реорганизация, изменение стратегий или запуск новых направлений могут влиять на количество вакансий. Например, компании могут увеличивать найм аналитиков данных и Data Scientist для поддержки новых инициатив.
#
# 6. *Технологические тренды*: Влияние новых технологий и методов может стимулировать спрос на специалистов в определенные периоды. Например, внедрение новых аналитических инструментов или методов машинного обучения может увеличить спрос на Data Scientist.
#
# Дополнительно, мы провели анализ новостей и событий за рассматриваемый период и вот несколько ключевых моментов:
#
# 1. *Сбер*: В новостях не было значительных изменений, которые могли бы напрямую повлиять на динамику вакансий. Однако, как крупная компания, Сбер может испытывать сезонные колебания в найме, связанные с внутренними проектами и стратегиями.
#
# 2. *Озон и Wildberries*: Оба маркетплейса показали убытки по итогам 2022 года, что связано с увеличением операционных расходов и стадией активного развития банковских подразделений. Это может объяснить колебания в количестве вакансий, так как компании могут корректировать свои стратегии найма в зависимости от финансовых результатов.
#
# 3. *Банк ВТБ (ПАО)*: В новостях не было значительных изменений, которые могли бы повлиять на динамику вакансий.
#
# 4. *Samokat.tech, Газпромбанк и Т1*: Для этих компаний также не было значительных новостей, которые могли бы объяснить изменения в количестве вакансий.
#
# В целом, выводы о сезонных колебаниях и влиянии внутренних изменений в компаниях подтверждаются. Увеличение или уменьшение количества вакансий может быть связано с финансовыми результатами, стратегическими изменениями и проектными циклами.
#
#
# #### 3.2.2. Мы проанализировали ТОП-5 работодателей в зависимости от грейда, указанного в вакансии.
#
# Мы проанализировали ТОП-5 работодателей в зависимости от грейда, указанной в вакансии.
# Для вакансии аналитика данных греда Junior (no experince) на первом месте стоит Сбер, у которого большего всего вакансий. Таже картина повторяется и для вакансии data scientist. Также компании Сбер первая по числу вакансий и для грейдов Junior+ (1-3 years), и Middle (3-6 years) обоих специальностей.
# Для грейда Senior (6+ years) вакансий аналитика данных на первом месте по числу вакансий стоит компания Леруа Мерлен, а для data scientist компания Fundraise Up
#
# #### 3.2.3. Мы проанлизровали зарплату в вакансиях.
# Предлагаемая работодателями зарплата на начальном грейде больше у вакансий "Data Scientist" (156 тыс.руб.) чем у вакансий специальности "Аналитик данных" (127 тыс.руб.). При этом к грейду Senior с требуемым опытом больше 6 лет уровень зарплаты выравниваются, но с сохранением лидирования уровня зарплаты у вакансий "Data Scientist" - 180 тыс. руб., против зарплаты у вакансий "Аналитик данных" - 178 тыс. руб.
#
# #### 3.2.4. Мы провели анализ средней зарплаты в разбивке по выбранному работодателю по регионам.
# Мы провели анализ средней зарплаты в разбивке по выбранному работадателю по регионам.
# Для анализа мы выбрали работадателя, у которого представлено больше всего вакансий - это Сбер.
# Мы видим, что самая высока зарплата как по вакансиям "Аналитик данных" так и по вакансиям "Data Scientist" -  в Москве, и уровень зарплата для обеих специальностей на уровне 175 тыс. руб. Самая низкая зарплата для вакансий "Аналитик данных" - это 47,5 тыс. руб. в Горно-Алтайске и для вакансий "Data Scientist" 75 тыс. руб. в Воронеже
#
# #### 3.2.5. Мы провели анализ средней зарплаты по месяцам в разбивке по грейдам.
#
# Мы провели анализ средней зарплаты по месяцам в разбивке по грейдам.
#
# *Для грейда Junior (no experience)*:
# Для вакансий "Аналитик данных" средняя зарплата в вакансиях уменьшилась в мае 2024 по сравнению с мартом 2024.
# Для вакансий "Data Scientist" в целом имелась динамика на снижение средней зарплаты, кроме апреля 2024, где мы видим рост по сравнению с другими месяцами.
#
# *Для грейда Junior+ (1-3 years)*:
# Для вакансий "Аналитик данных" средняя зарплата в вакансиях в период с марта 2024 по май 2024 находилась примерно на одном уровне 155 тыс. руб.
# Для вакансий "Data Scientist" ситуация аналогична предыдущему грейду, где мы видим скачок зарплаты до 170 тыс. руб. в апреле 2024.
#
# *Для грейда Middle (3-6 years)*:
# Для вакансий "Аналитик данных" средняя зарплата в вакансиях уменьшилась в мае 2024 по сравнению с мартом 2024.
# Для вакансий "Data Scientist" средняя зарплата примерно на одном уровне 175 тыс.руб.
#
# *Для грейда Senior (6+ years)*:
# Для вакансий "Аналитик данных" средняя зарплата в апреле выше, чем в мае 2024, вакансий за март нет.
# Для вакансий "Data Scientist" мы видим подъем средней зарплаты в мае до 190 тыс. руб. по сравнению в мартом и апрелем
#
# #### Общее наблюдение:
#
# 1. *Аналитик данных:*
#    - Видим, что средняя зарплата растет с уровнем опыта.
#    - Самая высокая зарплата у Senior аналитиков.
#    - Можно предположить, что с ростом опыта зарплата также увеличивается.
#
# 2. *Data Scientist:*
#    - Здесь также наблюдается рост зарплаты с уровнем опыта.
#    - Senior Data Scientist получают наибольшую зарплату.
#    - Возможно, опытные специалисты в этой области ценятся больше.
#
# #### 3.2.6. Мы провели анализ по типу занятости в вакансиях "Аналитик данных" и "Data Scientist" за период с марта 2024 по июнь 2024.
#
# Мы провели анализ по типу занятости, указанной в вакансиях "Аналитик данных" и "Data scientist" за период с марта 2024 по май 2024.
# В данных имеются 4 типа занятости: полная занятость, проектная работа, стажировка и частичная занятость.
# Для обеих вакансий превалирует полная занятость и составляет в среднем 97%
#
# #### 3.2.7. Мы провели анализ типичного места работы для Аналитика данных и Data Scientist по графику работы.
# Мы провели анализ типичного места работы для Аналитика данных и Data Scientist по Графику работы.
# В целом в вакансиях представлены 4 графика работы: это полный день, гибкий график, сменный график и удаленная работа.
# Для обеих вакансий превалирует полный день, для вакансии Data Scientis составляет 74% от всех вакансий, для Аналитика данных 80% всех вакансий.
# На последнем месте по условиям найма стоит сменный график и занимает в среднем 0,5% от всех вакансий
#
# ### 3.3. Мы провели анализ требуемых работодателями скиллов для обеих вакансий.
#
# Мы провели анализ требуемых работодателями скиллов для обоих вакансий. В результате анализа выявлено, что для вакансий "Аналитик данных" из 100 проанализированных скиллов 7% - это софт скиллы, а 93% это хард скиллы. Приблизительно такая же картина для вакансий "Data Scientist". 3% - это софт скиллы и 97% - это хард скиллы.
#
# ### 3.4. Мы проанализировали, к какому грейду и к какой специальности требований больше.
#
# Мы проанлизировали к какому грейду и к какой специальности требований больше.
# В результате анализа выявлено, что больше всего требований для обеих вакансий к грейду Senior (6+ years) и  меньше всего к Junior (no experince), что в целом является достаточно логичным.
#
# ### 3.5. Мы определили наиболее желаемых кандидатов на вакансии Аналитик данных и Data Scientist по следующим параметрам: самые важные hard-skils, самые важные soft-skils.
#
# Сравнение вакансий "Аналитик данных" и "Data Scientist" по важным навыкам
#
# #### Junior (no experience)
#
# *Data Scientist:*
# - *Hard skills:* Python, Machine Learning, ML, SQL, Анализ данных
# - *Soft skills:* Обучение и развитие
#
# *Аналитик данных:*
# - *Hard skills:* SQL, Python, Анализ данных, Аналитическое мышление, Работа с большим объемом информации
# - *Soft skills:* Работа в команде, Деловая коммуникация, Аналитический склад ума, Обучение и развитие
#
# *Выводы и наблюдения:*
# - Для обеих вакансий важны навыки Python и Анализ данных.
# - Data Scientist требует специфических навыков в области Machine Learning и ML, тогда как Аналитик данных акцентирует внимание на Аналитическом мышлении и работе с большим объемом информации.
# - Важные софт скиллы для Data Scientist включают Обучение и развитие, в то время как для Аналитика данных важны также Работа в команде и Деловая коммуникация.
#
# #### Junior+ (1-3 years)
#
# *Data Scientist:*
# - *Hard skills:* Python, SQL, Machine Learning, ML, NLP
# - *Soft skills:* Работа в команде, Аналитический склад ума, Управление рисками, Деловая коммуникация
#
# *Аналитик данных:*
# - *Hard skills:* SQL, Python, Анализ данных, Аналитическое мышление, Работа с большим объемом информации
# - *Soft skills:* Деловая коммуникация, Аналитический склад ума, Работа в команде, Умение принимать решения, Системное мышление
#
# *Выводы и наблюдения:*
# - Оба направления требуют навыков Python и SQL.
# - Data Scientist требует дополнительных навыков в области NLP и управления рисками.
# - Аналитик данных акцентирует внимание на Умении принимать решения и Системном мышлении.
#
# #### Middle (3-6 years)
#
# *Data Scientist:*
# - *Hard skills:* Python, SQL, ML, Machine Learning, NLP
# - *Soft skills:* Управление командой, Работа в команде, Обучение и развитие, Управление рисками, Деловая коммуникация
#
# *Аналитик данных:*
# - *Hard skills:* SQL, Python, Анализ данных, Аналитическое мышление, Работа с большим объемом информации
# - *Soft skills:* Системное мышление, Работа в команде, Обучение и развитие, Деловая коммуникация, Управление командой
#
# *Выводы и наблюдения:*
# - Оба направления требуют навыков Python и SQL.
# - Data Scientist требует навыков NLP и управления рисками.
# - Аналитик данных акцентирует внимание на Системном мышлении и управлении командой.
#
# #### Senior (6+ years)
#
# *Data Scientist:*
# - *Hard skills:* Python, SQL, Анализ данных, ML, Machine Learning
# - *Soft skills:* Управление командой, Управление рисками
#
# *Аналитик данных:*
# - *Hard skills:* SQL, Python, Machine Learning, Аналитическое мышление, Анализ данных
# - *Soft skills:* Управление командой, Управление рисками
#
# *Выводы и наблюдения:*
# - Для обеих вакансий важны навыки Python, SQL и Анализ данных.
# - Оба направления требуют навыков Machine Learning и управления командой.
# - Важные софт скиллы для обеих вакансий включают Управление рисками.
#
# ### Общие выводы:
# - Python и SQL являются ключевыми навыками для обеих вакансий на всех уровнях.
# - Data Scientist требует более специфических навыков в области Machine Learning и NLP.
# - Аналитик данных акцентирует внимание на Аналитическом мышлении и работе с большим объемом информации.
# - Софт скиллы, такие как Работа в команде и Деловая коммуникация, важны для обеих вакансий, но для Data Scientist также важны навыки управления рисками.
#
# ### 3.6. Мы провели расчет помесячной динамики количества вакансий для Аналитика данных и Data Scientist за период с февраля 2024 по июнь 2024.
#
# Мы провели расчет помесячной динамики количества вакансий для Аналитика данных и Data Scientist за период с марта 2024 по май 2024.
# В результате анализа выявлено, что в целом больше всего вакансий для грейда Junior+ (1-3 years) специальности "Аналитик данных" и грейда Middle (3-6 years) специальности "Data Scientist".
# Для вакансий "Аналитик данных" мы видим пик количества вакансий в мае 2024.
# Для вакансий "Data Scientist" мы видим пик вакансий в апреле 2024 года.
#
# ## *Рекомендации:*
#
# 1. **Для разработчиков сайта HH.ru**. При формировании вакансий разделить поля, куда работодатель вносит данные по требуемым скиллам, на софт скиллы и хард скиллы, что позволит упростить обработку данных для проведения дальнейшего анализа.
# 2. **Для пользователей сайта HH.ru, в частности работодателей**. Внедрить регулярный мониторинг и анализ динамики зарплат по грейдам и регионам, чтобы своевременно реагировать на изменения.
# 3. **Для пользователей сайта HH.ru, в частности соискателей.**
#
# ### Рекомендации к развитию по карьерной лестнице
#
# **1. Аналитик данных:**
#
# Если вы на начальном уровне (Junior), рекомендую начать с вакансии "Аналитик данных". Это позволит вам получить опыт работы с SQL, Python и анализом данных.
# Постепенно развивайте навыки в области NLP и управления рисками, чтобы перейти на уровень Junior+.
# Для роста к Middle и Senior уровням, углубляйтесь в анализ данных, системное мышление и управление командой
#
# **2. Data Scientist:**
#
# - Если вас интересует машинное обучение и анализ данных, начните с вакансии "Data Scientist".
# - На уровне Junior, углубляйтесь в Python, SQL и ML.
# - Для перехода к Middle и Senior уровням, изучайте анализ данных, визуализацию и решайте более сложные задачи.
#
# **3. Выбор работодателя:**
#
# - Если вы хотите максимизировать зарплату, обратите внимание на Москву, где предложения для обеих вакансий выше.
# - Если важен регион, выберите вакансии в соответствующем городе.
#
# **4. Рост:**
#
# - Следите за динамикой зарплаты по месяцам и стремитесь к росту опыта и навыков.
#
# **5. Зарплата:**
#
# Сравнивая рост зарплаты от грейда к грейду и максимальные зарплаты, обе специальности имеют свои преимущества:
# 1. Аналитик данных:
# Начальная зарплата для аналитика данных может быть ниже, но с ростом опыта она увеличивается.
# Максимальная зарплата для аналитика данных в Москве составляет примерно 180 000 рублей.
# Аналитики данных могут заниматься разнообразными задачами, включая анализ данных, визуализацию и оптимизацию рабочих процессов.
# 2. Data Scientist:
# Data Scientist начинают с более высокой зарплаты, чем аналитики, и могут зарабатывать от 150 000 рублей до 400 000 рублей в месяц.
# Максимальная зарплата для Data Scientist также выше, чем для аналитика данных.
# Data Scientist занимаются более сложными задачами, включая машинное обучение, анализ больших объемов данных и прогнозирование.
#
# **Итак, если вы хотите начать с более высокой зарплаты и интересуетесь машинным обучением, Data Scientist может быть лучшим выбором. Если вас больше привлекает анализ данных и оптимизация процессов, то аналитик данных также является хорошим вариантом. Важно учесть свои интересы, навыки и карьерные цели при выборе специальности.**
